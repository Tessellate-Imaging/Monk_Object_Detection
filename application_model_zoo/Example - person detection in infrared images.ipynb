# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/3_mxrcnn/Example%20-%20person%20detection%20in%20infrared%20images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## 1. Installattion Instructions
#
#
#
# ## 2. Use trained model to detect person in infrared images
#
#
#
# ## 3. How to train using camel infrared dataset

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/3_mxrcnn/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/3_mxrcnn/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install


# For Local systems and cloud select the right CUDA version
#! cd Monk_Object_Detection/3_mxrcnn/installation && cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# # Use already trained model for demo

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from infer_base import *

# %%
# Download trained model

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1f4alKjclAoAq6m_6gKGgzW_dhfHxJhWb' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1f4alKjclAoAq6m_6gKGgzW_dhfHxJhWb" -O infrared_person_trained.zip && rm -rf /tmp/cookies.txt

# %%
https://drive.google.com/file/d//view?usp=sharing

# %%
class_file = set_class_list("infrared_person_trained/classes.txt");

# %%
#Model - Select the model as per number of iterations it has been trained for

# %%
set_model_params(model_name="vgg16", model_path="infrared_person_trained/model_vgg16-0100.params");

# %%
#Hyper Params

# %%
set_hyper_params(gpus="0", batch_size=1);

# %%
# Preprocessing

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
#Initalization

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
#Network

# %%
sym = set_network();
mod = load_model(sym);

# %%
#Load Image and infer

# %%
set_output_params(vis_thresh=0.9, vis=True)
output = Infer("Monk_Object_Detection/example_notebooks/sample_dataset/ir_dataset_test/1.jpg", mod);
# Out:
# person
#  0.9978498220443726 [141.6039453125, 100.14171875, 162.0447265625, 148.62283854166665]
# ['person\n', 0.9978498220443726, [141.6039453125, 100.14171875, 162.0447265625, 148.62283854166665]]

# %%
set_output_params(vis_thresh=0.9, vis=True)
output = Infer("Monk_Object_Detection/example_notebooks/sample_dataset/ir_dataset_test/2.jpg", mod);
# Out:
# person
#  0.9800990223884583 [119.29251302083334, 100.46216796875, 138.0158984375, 143.18489583333334]
# person
#  0.9761733412742615 [173.52393229166665, 99.7019140625, 189.694375, 137.56904947916667]
# ['person\n', 0.9800990223884583, [119.29251302083334, 100.46216796875, 138.0158984375, 143.18489583333334]]

# %% [markdown]
# # Train you own detector

# %% [markdown]
# # Download Dataset
#
# - credits: https://camel.ece.gatech.edu/

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1LSBBmntmLAloPO5Cc3ar61ranfBx8D8W' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1LSBBmntmLAloPO5Cc3ar61ranfBx8D8W" -O ir_dataset.zip && rm -rf /tmp/cookies.txt

# %%
! unzip ir_dataset.zip

# %% [markdown]
# # Desired annotation - COCO Format
#
# ## Dataset Directory Structure
#
#     ./ (root_dir)
#           |
#           |------openlogo (coco_dir)
#           |         |
#           |         |---JPEGImages (img_dir)
#           |         |----|
#           |              |-------------------img1.jpg
#           |              |-------------------img2.jpg
#           |              |-------------------.........(and so on)
#           |
#           |
#           |         |---annotations (anno_dir)
#           |         |----|
#           |              |--------------------instances_Images.json
#           |              |--------------------classes.txt
#
#
#  - instances_Train.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order

# %% [markdown]
# # Annotation Conversion - Monk format to COCO

# %%
import os
import numpy as np 
import cv2
import dicttoxml
import xml.etree.ElementTree as ET
from xml.dom.minidom import parseString
from tqdm import tqdm
import shutil
import json
import pandas as pd

# %%
# Provide details on directory in Monk Format

# %%
root = "ir_dataset";
img_dir = "images/";
anno_file = "train_labels.csv";

# %%
# Need not change anything below

# %%
dataset_path = root;
images_folder = root + "/" + img_dir;
annotations_path = root + "/annotations/";

# %%
if not os.path.isdir(annotations_path):
    os.mkdir(annotations_path)
    
input_images_folder = images_folder;
input_annotations_path = root + "/" + anno_file;

# %%
output_dataset_path = root;
output_image_folder = input_images_folder;
output_annotation_folder = annotations_path;

tmp = img_dir.replace("/", "");
output_annotation_file = output_annotation_folder + "/instances_" + tmp + ".json";
output_classes_file = output_annotation_folder + "/classes.txt";

# %%
if not os.path.isdir(output_annotation_folder):
    os.mkdir(output_annotation_folder);

# %%
df = pd.read_csv(input_annotations_path);
columns = df.columns

# %%
delimiter = " ";

# %%
list_dict = [];
anno = [];
for i in range(len(df)):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    for j in range(len(tmp)//5):
        label = tmp[j*5+4];
        if(label not in anno):
            anno.append(label);
    anno = sorted(anno)
    
for i in tqdm(range(len(anno))):
    tmp = {};
    tmp["supercategory"] = "master";
    tmp["id"] = i;
    tmp["name"] = anno[i];
    list_dict.append(tmp);

anno_f = open(output_classes_file, 'w');
for i in range(len(anno)):
    anno_f.write(anno[i] + "\n");
anno_f.close();
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 5599.87it/s]

# %%
coco_data = {};
coco_data["type"] = "instances";
coco_data["images"] = [];
coco_data["annotations"] = [];
coco_data["categories"] = list_dict;
image_id = 0;
annotation_id = 0;


for i in tqdm(range(len(df))):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    image_in_path = input_images_folder + "/" + img_name;
    img = cv2.imread(image_in_path, 1);
    h, w, c = img.shape;

    images_tmp = {};
    images_tmp["file_name"] = img_name;
    images_tmp["height"] = h;
    images_tmp["width"] = w;
    images_tmp["id"] = image_id;
    coco_data["images"].append(images_tmp);
    

    for j in range(len(tmp)//5):
        x1 = int(tmp[j*5+0]);
        y1 = int(tmp[j*5+1]);
        x2 = int(tmp[j*5+2]);
        y2 = int(tmp[j*5+3]);
        label = tmp[j*5+4];
        annotations_tmp = {};
        annotations_tmp["id"] = annotation_id;
        annotation_id += 1;
        annotations_tmp["image_id"] = image_id;
        annotations_tmp["segmentation"] = [];
        annotations_tmp["ignore"] = 0;
        annotations_tmp["area"] = (x2-x1)*(y2-y1);
        annotations_tmp["iscrowd"] = 0;
        annotations_tmp["bbox"] = [x1, y1, x2-x1, y2-y1];
        annotations_tmp["category_id"] = anno.index(label);

        coco_data["annotations"].append(annotations_tmp)
    image_id += 1;

outfile =  open(output_annotation_file, 'w');
json_str = json.dumps(coco_data, indent=4);
outfile.write(json_str);
outfile.close();
# Out:
# 100%|██████████| 4703/4703 [00:04<00:00, 1085.19it/s]

# %% [markdown]
# # Training

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from train_base import *

# %%
# Dataset params

# %%
root_dir = "./";
coco_dir = "ir_dataset";
img_dir = "images";

# %%
set_dataset_params(root_dir=root_dir, 
                   coco_dir=coco_dir, imageset=img_dir);

# %%
# Model Type

# %%
set_model_params(model_name="vgg16");

# %%
# Hyper Params

# %%
set_hyper_params(gpus="0", lr=0.001, lr_decay_epoch="1", epochs=2, batch_size=2);

# %%
set_output_params(log_interval=100, save_prefix="model_vgg16");

# %%
# Preprocessing params

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
# Initialize params

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
# Remove caches if any

# %%
if os.path.isdir("./cache/"):
    os.system("rm -r ./cache/")

# %%
# Invoke Dataloader

# %%
roidb = set_dataset();
# Out:
# INFO:root:computing cache ./cache/coco_images_roidb.pkl
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# INFO:root:saving cache ./cache/coco_images_roidb.pkl
# INFO:root:coco_images num_images 4703
# INFO:root:filter roidb: 4703 -> 4703
# INFO:root:coco_images append flipped images to roidb

# %%
#Network

# %%
sym = set_network();

# %%
# Train

# %%
train(sym, roidb);
# Out:
# INFO:root:max input shape
# {'bbox_target': (2, 36, 62, 62),
#  'bbox_weight': (2, 36, 62, 62),
#  'data': (2, 3, 1000, 1000),
#  'gt_boxes': (2, 100, 5),
#  'im_info': (2, 3),
#  'label': (2, 1, 558, 62)}
# INFO:root:max output shape
# {'bbox_loss_reshape_output': (2, 64, 8),
#  'blockgrad0_output': (2, 64),
#  'cls_prob_reshape_output': (2, 64, 2),
#  'rpn_bbox_loss_output': (2, 36, 62, 62),
#  'rpn_cls_prob_output': (2, 2, 558, 62)}
# INFO:root:locking params
# ['conv1_1_weight',
#  'conv1_1_bias',
#  'conv1_2_weight',
#  'conv1_2_bias',
#  'conv2_1_weight',
#  'conv2_1_bias',
#  'conv2_2_weight',
#  'conv2_2_bias',
#  'conv3_1_weight',
#  'conv3_1_bias',
#  'conv3_2_weight',
#  'conv3_2_bias',
#  'conv3_3_weight',
#  'conv3_3_bias',
#  'conv4_1_weight',
#  'conv4_1_bias',
#  'conv4_2_weight',
#  'conv4_2_bias',
#  'conv4_3_weight',
#  'conv4_3_bias']
# INFO:root:lr 0.001000 lr_epoch_diff [1] lr_iters [4703]
# INFO:root:Epoch[0] Batch [0-100]	Speed: 7.07 samples/sec	RPNAcc=0.969543	RPNLogLoss=0.104563	RPNL1Loss=0.567828	RCNNAcc=0.965501	RCNNLogLoss=0.083347	RCNNL1Loss=1.409450
# INFO:root:Epoch[0] Batch [0-200]	Speed: 7.53 samples/sec	RPNAcc=0.983666	RPNLogLoss=0.056409	RPNL1Loss=0.527054	RCNNAcc=0.981693	RCNNLogLoss=0.044421	RCNNL1Loss=1.274534
# INFO:root:Epoch[0] Batch [0-300]	Speed: 7.04 samples/sec	RPNAcc=0.989092	RPNLogLoss=0.037941	RPNL1Loss=0.527054	RCNNAcc=0.986919	RCNNLogLoss=0.031502	RCNNL1Loss=1.158374
# INFO:root:Epoch[0] Batch [0-400]	Speed: 6.18 samples/sec	RPNAcc=0.991812	RPNLogLoss=0.028656	RPNL1Loss=0.527054	RCNNAcc=0.990025	RCNNLogLoss=0.024391	RCNNL1Loss=1.013734
# INFO:root:Epoch[0] Batch [0-500]	Speed: 6.66 samples/sec	RPNAcc=0.993447	RPNLogLoss=0.023014	RPNL1Loss=0.527054	RCNNAcc=0.991860	RCNNLogLoss=0.019998	RCNNL1Loss=0.913790
# INFO:root:Epoch[0] Batch [0-600]	Speed: 7.04 samples/sec	RPNAcc=0.994537	RPNLogLoss=0.019237	RPNL1Loss=0.527054	RCNNAcc=0.993175	RCNNLogLoss=0.016809	RCNNL1Loss=0.863155
# INFO:root:Epoch[0] Batch [0-700]	Speed: 5.09 samples/sec	RPNAcc=0.994659	RPNLogLoss=0.019037	RPNL1Loss=0.442266	RCNNAcc=0.992578	RCNNLogLoss=0.019287	RCNNL1Loss=0.824630
# INFO:root:Epoch[0] Batch [0-800]	Speed: 5.90 samples/sec	RPNAcc=0.993163	RPNLogLoss=0.022022	RPNL1Loss=0.446344	RCNNAcc=0.990783	RCNNLogLoss=0.024308	RCNNL1Loss=0.814858
# INFO:root:Epoch[0] Batch [0-900]	Speed: 7.79 samples/sec	RPNAcc=0.993638	RPNLogLoss=0.020490	RPNL1Loss=0.453872	RCNNAcc=0.990332	RCNNLogLoss=0.024914	RCNNL1Loss=0.853764
# INFO:root:Epoch[0] Batch [0-1000]	Speed: 7.65 samples/sec	RPNAcc=0.993766	RPNLogLoss=0.019899	RPNL1Loss=0.465473	RCNNAcc=0.990416	RCNNLogLoss=0.024758	RCNNL1Loss=0.898342
# INFO:root:Epoch[0] Batch [0-1100]	Speed: 7.57 samples/sec	RPNAcc=0.993972	RPNLogLoss=0.019291	RPNL1Loss=0.462011	RCNNAcc=0.990087	RCNNLogLoss=0.025661	RCNNL1Loss=0.951301
# INFO:root:Epoch[0] Batch [0-1200]	Speed: 3.63 samples/sec	RPNAcc=0.993423	RPNLogLoss=0.021840	RPNL1Loss=0.465990	RCNNAcc=0.985012	RCNNLogLoss=0.036803	RCNNL1Loss=1.110197
# INFO:root:Epoch[0] Batch [0-1300]	Speed: 3.68 samples/sec	RPNAcc=0.993270	RPNLogLoss=0.022534	RPNL1Loss=0.395242	RCNNAcc=0.983336	RCNNLogLoss=0.041341	RCNNL1Loss=1.151560
# INFO:root:Epoch[0] Batch [0-1400]	Speed: 2.52 samples/sec	RPNAcc=0.992733	RPNLogLoss=0.024223	RPNL1Loss=0.376022	RCNNAcc=0.977226	RCNNLogLoss=0.053962	RCNNL1Loss=1.221711
# INFO:root:Epoch[0] Batch [0-1500]	Speed: 2.05 samples/sec	RPNAcc=0.992504	RPNLogLoss=0.024720	RPNL1Loss=0.333280	RCNNAcc=0.971967	RCNNLogLoss=0.065171	RCNNL1Loss=1.253600
# INFO:root:Epoch[0] Batch [0-1600]	Speed: 2.42 samples/sec	RPNAcc=0.992333	RPNLogLoss=0.025234	RPNL1Loss=0.328208	RCNNAcc=0.968638	RCNNLogLoss=0.072449	RCNNL1Loss=1.277516
# INFO:root:Epoch[0] Batch [0-1700]	Speed: 2.71 samples/sec	RPNAcc=0.991941	RPNLogLoss=0.026212	RPNL1Loss=0.316243	RCNNAcc=0.965448	RCNNLogLoss=0.079745	RCNNL1Loss=1.276414
# INFO:root:Epoch[0] Batch [0-1800]	Speed: 3.29 samples/sec	RPNAcc=0.991590	RPNLogLoss=0.026909	RPNL1Loss=0.307026	RCNNAcc=0.962269	RCNNLogLoss=0.087153	RCNNL1Loss=1.270765
# INFO:root:Epoch[0] Batch [0-1900]	Speed: 2.34 samples/sec	RPNAcc=0.991344	RPNLogLoss=0.027819	RPNL1Loss=0.285799	RCNNAcc=0.959585	RCNNLogLoss=0.093343	RCNNL1Loss=1.267183
# INFO:root:Epoch[0] Batch [0-2000]	Speed: 1.84 samples/sec	RPNAcc=0.990840	RPNLogLoss=0.029063	RPNL1Loss=0.266613	RCNNAcc=0.956143	RCNNLogLoss=0.100589	RCNNL1Loss=1.268323
# INFO:root:Epoch[0] Batch [0-2100]	Speed: 2.24 samples/sec	RPNAcc=0.990987	RPNLogLoss=0.029084	RPNL1Loss=0.253976	RCNNAcc=0.954835	RCNNLogLoss=0.104184	RCNNL1Loss=1.256878
# INFO:root:Epoch[0] Batch [0-2200]	Speed: 4.78 samples/sec	RPNAcc=0.991134	RPNLogLoss=0.028622	RPNL1Loss=0.254431	RCNNAcc=0.955585	RCNNLogLoss=0.102725	RCNNL1Loss=1.234586
# INFO:root:Epoch[0] Batch [0-2300]	Speed: 5.54 samples/sec	RPNAcc=0.991471	RPNLogLoss=0.027646	RPNL1Loss=0.251392	RCNNAcc=0.956656	RCNNLogLoss=0.100565	RCNNL1Loss=1.196439
# INFO:root:Epoch[0] Batch [0-2400]	Speed: 5.86 samples/sec	RPNAcc=0.991693	RPNLogLoss=0.026969	RPNL1Loss=0.250131	RCNNAcc=0.957358	RCNNLogLoss=0.099336	RCNNL1Loss=1.166874
# INFO:root:Epoch[0] Batch [0-2500]	Speed: 7.38 samples/sec	RPNAcc=0.991991	RPNLogLoss=0.026016	RPNL1Loss=0.248564	RCNNAcc=0.958804	RCNNLogLoss=0.096129	RCNNL1Loss=1.144176
# INFO:root:Epoch[0] Batch [0-2600]	Speed: 7.57 samples/sec	RPNAcc=0.992275	RPNLogLoss=0.025067	RPNL1Loss=0.248564	RCNNAcc=0.960271	RCNNLogLoss=0.092774	RCNNL1Loss=1.140962
# INFO:root:Epoch[0] Batch [0-2700]	Speed: 6.50 samples/sec	RPNAcc=0.992555	RPNLogLoss=0.024155	RPNL1Loss=0.248564	RCNNAcc=0.961611	RCNNLogLoss=0.089786	RCNNL1Loss=1.134461
# INFO:root:Epoch[0] Batch [0-2800]	Speed: 6.42 samples/sec	RPNAcc=0.992815	RPNLogLoss=0.023313	RPNL1Loss=0.248564	RCNNAcc=0.962873	RCNNLogLoss=0.086885	RCNNL1Loss=1.127618
# INFO:root:Epoch[0] Batch [0-2900]	Speed: 7.16 samples/sec	RPNAcc=0.993063	RPNLogLoss=0.022515	RPNL1Loss=0.248564	RCNNAcc=0.964064	RCNNLogLoss=0.084180	RCNNL1Loss=1.122873
# INFO:root:Epoch[0] Batch [0-3000]	Speed: 7.15 samples/sec	RPNAcc=0.993250	RPNLogLoss=0.021940	RPNL1Loss=0.247948	RCNNAcc=0.965176	RCNNLogLoss=0.081600	RCNNL1Loss=1.113519
# INFO:root:Epoch[0] Batch [0-3100]	Speed: 4.72 samples/sec	RPNAcc=0.993220	RPNLogLoss=0.021956	RPNL1Loss=0.246256	RCNNAcc=0.965845	RCNNLogLoss=0.080294	RCNNL1Loss=1.077851
# INFO:root:Epoch[0] Batch [0-3200]	Speed: 7.71 samples/sec	RPNAcc=0.993261	RPNLogLoss=0.021728	RPNL1Loss=0.249766	RCNNAcc=0.966712	RCNNLogLoss=0.078442	RCNNL1Loss=1.079950
# INFO:root:Epoch[0] Batch [0-3300]	Speed: 7.64 samples/sec	RPNAcc=0.993408	RPNLogLoss=0.021235	RPNL1Loss=0.250348	RCNNAcc=0.967593	RCNNLogLoss=0.076463	RCNNL1Loss=1.081050
# INFO:root:Epoch[0] Batch [0-3400]	Speed: 7.69 samples/sec	RPNAcc=0.993508	RPNLogLoss=0.020871	RPNL1Loss=0.251609	RCNNAcc=0.968307	RCNNLogLoss=0.074864	RCNNL1Loss=1.080868
# INFO:root:Epoch[0] Batch [0-3500]	Speed: 7.57 samples/sec	RPNAcc=0.993589	RPNLogLoss=0.020553	RPNL1Loss=0.251951	RCNNAcc=0.969018	RCNNLogLoss=0.073346	RCNNL1Loss=1.082672
# INFO:root:Epoch[0] Batch [0-3600]	Speed: 2.84 samples/sec	RPNAcc=0.993521	RPNLogLoss=0.020752	RPNL1Loss=0.251052	RCNNAcc=0.968034	RCNNLogLoss=0.075607	RCNNL1Loss=1.086699
# INFO:root:Epoch[0] Batch [0-3700]	Speed: 3.70 samples/sec	RPNAcc=0.993470	RPNLogLoss=0.020882	RPNL1Loss=0.248814	RCNNAcc=0.967844	RCNNLogLoss=0.076260	RCNNL1Loss=1.086618
# INFO:root:Epoch[0] Batch [0-3800]	Speed: 1.89 samples/sec	RPNAcc=0.993289	RPNLogLoss=0.021409	RPNL1Loss=0.245340	RCNNAcc=0.965963	RCNNLogLoss=0.080208	RCNNL1Loss=1.094549
# INFO:root:Epoch[0] Batch [0-3900]	Speed: 2.64 samples/sec	RPNAcc=0.993324	RPNLogLoss=0.021293	RPNL1Loss=0.240617	RCNNAcc=0.965119	RCNNLogLoss=0.082109	RCNNL1Loss=1.096466
# INFO:root:Epoch[0] Batch [0-4000]	Speed: 2.12 samples/sec	RPNAcc=0.993126	RPNLogLoss=0.021906	RPNL1Loss=0.242109	RCNNAcc=0.963786	RCNNLogLoss=0.085221	RCNNL1Loss=1.099634
# INFO:root:Epoch[0] Batch [0-4100]	Speed: 3.27 samples/sec	RPNAcc=0.993143	RPNLogLoss=0.021854	RPNL1Loss=0.238793	RCNNAcc=0.963224	RCNNLogLoss=0.086662	RCNNL1Loss=1.090298
# INFO:root:Epoch[0] Batch [0-4200]	Speed: 3.03 samples/sec	RPNAcc=0.993075	RPNLogLoss=0.022039	RPNL1Loss=0.235766	RCNNAcc=0.962252	RCNNLogLoss=0.088788	RCNNL1Loss=1.086945
# INFO:root:Epoch[0] Batch [0-4300]	Speed: 1.90 samples/sec	RPNAcc=0.992931	RPNLogLoss=0.022486	RPNL1Loss=0.226552	RCNNAcc=0.961112	RCNNLogLoss=0.091338	RCNNL1Loss=1.086202
# INFO:root:Epoch[0] Batch [0-4400]	Speed: 1.95 samples/sec	RPNAcc=0.992893	RPNLogLoss=0.022590	RPNL1Loss=0.219817	RCNNAcc=0.960554	RCNNLogLoss=0.092774	RCNNL1Loss=1.082283
# INFO:root:Epoch[0] Batch [0-4500]	Speed: 3.18 samples/sec	RPNAcc=0.992956	RPNLogLoss=0.022523	RPNL1Loss=0.217855	RCNNAcc=0.960396	RCNNLogLoss=0.093393	RCNNL1Loss=1.074359
# INFO:root:Epoch[0] Batch [0-4600]	Speed: 5.46 samples/sec	RPNAcc=0.993019	RPNLogLoss=0.022316	RPNL1Loss=0.216844	RCNNAcc=0.960949	RCNNLogLoss=0.092223	RCNNL1Loss=1.061016
# INFO:root:Epoch[0] Batch [0-4700]	Speed: 5.13 samples/sec	RPNAcc=0.993150	RPNLogLoss=0.021951	RPNL1Loss=0.215751	RCNNAcc=0.961371	RCNNLogLoss=0.091356	RCNNL1Loss=1.045654
# INFO:root:Epoch[0] Train-RPNAcc=0.993153
# INFO:root:Epoch[0] Train-RPNLogLoss=0.021942
# INFO:root:Epoch[0] Train-RPNL1Loss=0.215724
# INFO:root:Epoch[0] Train-RCNNAcc=0.961386
# INFO:root:Epoch[0] Train-RCNNLogLoss=0.091327
# INFO:root:Epoch[0] Train-RCNNL1Loss=1.045292
# INFO:root:Epoch[0] Time cost=2418.943
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0001.params"
# INFO:root:Update[4704]: Change learning rate to 1.00000e-04
# INFO:root:Epoch[1] Batch [0-100]	Speed: 7.19 samples/sec	RPNAcc=0.997641	RPNLogLoss=0.007741	RPNL1Loss=0.254498	RCNNAcc=0.978110	RCNNLogLoss=0.063086	RCNNL1Loss=0.828970
# INFO:root:Epoch[1] Batch [0-200]	Speed: 7.54 samples/sec	RPNAcc=0.998387	RPNLogLoss=0.005167	RPNL1Loss=0.246599	RCNNAcc=0.987679	RCNNLogLoss=0.035766	RCNNL1Loss=0.746405
# INFO:root:Epoch[1] Batch [0-300]	Speed: 7.10 samples/sec	RPNAcc=0.998877	RPNLogLoss=0.003581	RPNL1Loss=0.246599	RCNNAcc=0.989981	RCNNLogLoss=0.028053	RCNNL1Loss=0.726769
# INFO:root:Epoch[1] Batch [0-400]	Speed: 6.27 samples/sec	RPNAcc=0.999094	RPNLogLoss=0.002844	RPNL1Loss=0.246599	RCNNAcc=0.991798	RCNNLogLoss=0.023076	RCNNL1Loss=0.679709
# INFO:root:Epoch[1] Batch [0-500]	Speed: 6.76 samples/sec	RPNAcc=0.999255	RPNLogLoss=0.002360	RPNL1Loss=0.246599	RCNNAcc=0.992546	RCNNLogLoss=0.020769	RCNNL1Loss=0.653628
# INFO:root:Epoch[1] Batch [0-600]	Speed: 7.60 samples/sec	RPNAcc=0.999292	RPNLogLoss=0.002206	RPNL1Loss=0.246599	RCNNAcc=0.993318	RCNNLogLoss=0.018720	RCNNL1Loss=0.641486
# INFO:root:Epoch[1] Batch [0-700]	Speed: 5.52 samples/sec	RPNAcc=0.998604	RPNLogLoss=0.004013	RPNL1Loss=0.276251	RCNNAcc=0.993090	RCNNLogLoss=0.019392	RCNNL1Loss=0.620650
# INFO:root:Epoch[1] Batch [0-800]	Speed: 5.91 samples/sec	RPNAcc=0.997671	RPNLogLoss=0.006456	RPNL1Loss=0.385214	RCNNAcc=0.992295	RCNNLogLoss=0.021440	RCNNL1Loss=0.602575
# INFO:root:Epoch[1] Batch [0-900]	Speed: 7.85 samples/sec	RPNAcc=0.997717	RPNLogLoss=0.006428	RPNL1Loss=0.401831	RCNNAcc=0.992508	RCNNLogLoss=0.021054	RCNNL1Loss=0.663457
# INFO:root:Epoch[1] Batch [0-1000]	Speed: 7.68 samples/sec	RPNAcc=0.997376	RPNLogLoss=0.007099	RPNL1Loss=0.396668	RCNNAcc=0.992453	RCNNLogLoss=0.021344	RCNNL1Loss=0.704478
# INFO:root:Epoch[1] Batch [0-1100]	Speed: 7.59 samples/sec	RPNAcc=0.997238	RPNLogLoss=0.007416	RPNL1Loss=0.387966	RCNNAcc=0.992755	RCNNLogLoss=0.020812	RCNNL1Loss=0.747650
# INFO:root:Epoch[1] Batch [0-1200]	Speed: 3.65 samples/sec	RPNAcc=0.996922	RPNLogLoss=0.008222	RPNL1Loss=0.363153	RCNNAcc=0.989156	RCNNLogLoss=0.029108	RCNNL1Loss=0.817185
# INFO:root:Epoch[1] Batch [0-1300]	Speed: 3.65 samples/sec	RPNAcc=0.996427	RPNLogLoss=0.009430	RPNL1Loss=0.329291	RCNNAcc=0.986963	RCNNLogLoss=0.034556	RCNNL1Loss=0.871213
# INFO:root:Epoch[1] Batch [0-1400]	Speed: 2.51 samples/sec	RPNAcc=0.995965	RPNLogLoss=0.010763	RPNL1Loss=0.306701	RCNNAcc=0.982395	RCNNLogLoss=0.044608	RCNNL1Loss=0.920412
# INFO:root:Epoch[1] Batch [0-1500]	Speed: 2.02 samples/sec	RPNAcc=0.995422	RPNLogLoss=0.012117	RPNL1Loss=0.271205	RCNNAcc=0.977796	RCNNLogLoss=0.054852	RCNNL1Loss=0.949371
# INFO:root:Epoch[1] Batch [0-1600]	Speed: 2.39 samples/sec	RPNAcc=0.995031	RPNLogLoss=0.013169	RPNL1Loss=0.265029	RCNNAcc=0.974781	RCNNLogLoss=0.061477	RCNNL1Loss=0.967083
# INFO:root:Epoch[1] Batch [0-1700]	Speed: 2.68 samples/sec	RPNAcc=0.994817	RPNLogLoss=0.013996	RPNL1Loss=0.257695	RCNNAcc=0.972066	RCNNLogLoss=0.067676	RCNNL1Loss=0.961924
# INFO:root:Epoch[1] Batch [0-1800]	Speed: 3.30 samples/sec	RPNAcc=0.994540	RPNLogLoss=0.014893	RPNL1Loss=0.248761	RCNNAcc=0.969665	RCNNLogLoss=0.073371	RCNNL1Loss=0.967121
# INFO:root:Epoch[1] Batch [0-1900]	Speed: 2.33 samples/sec	RPNAcc=0.994446	RPNLogLoss=0.015561	RPNL1Loss=0.231063	RCNNAcc=0.967981	RCNNLogLoss=0.077688	RCNNL1Loss=0.964289
# INFO:root:Epoch[1] Batch [0-2000]	Speed: 1.82 samples/sec	RPNAcc=0.994036	RPNLogLoss=0.016833	RPNL1Loss=0.217070	RCNNAcc=0.965623	RCNNLogLoss=0.083090	RCNNL1Loss=0.976123
# INFO:root:Epoch[1] Batch [0-2100]	Speed: 2.21 samples/sec	RPNAcc=0.994098	RPNLogLoss=0.016995	RPNL1Loss=0.208266	RCNNAcc=0.964671	RCNNLogLoss=0.085826	RCNNL1Loss=0.974448
# INFO:root:Epoch[1] Batch [0-2200]	Speed: 4.73 samples/sec	RPNAcc=0.994128	RPNLogLoss=0.016930	RPNL1Loss=0.208374	RCNNAcc=0.965172	RCNNLogLoss=0.084843	RCNNL1Loss=0.961961
# INFO:root:Epoch[1] Batch [0-2300]	Speed: 5.50 samples/sec	RPNAcc=0.994345	RPNLogLoss=0.016364	RPNL1Loss=0.205838	RCNNAcc=0.965973	RCNNLogLoss=0.083213	RCNNL1Loss=0.936493
# INFO:root:Epoch[1] Batch [0-2400]	Speed: 5.86 samples/sec	RPNAcc=0.994475	RPNLogLoss=0.016029	RPNL1Loss=0.204691	RCNNAcc=0.966410	RCNNLogLoss=0.082229	RCNNL1Loss=0.915195
# INFO:root:Epoch[1] Batch [0-2500]	Speed: 7.39 samples/sec	RPNAcc=0.994675	RPNLogLoss=0.015490	RPNL1Loss=0.204016	RCNNAcc=0.967522	RCNNLogLoss=0.079667	RCNNL1Loss=0.901724
# INFO:root:Epoch[1] Batch [0-2600]	Speed: 7.54 samples/sec	RPNAcc=0.994851	RPNLogLoss=0.014964	RPNL1Loss=0.204016	RCNNAcc=0.968702	RCNNLogLoss=0.076864	RCNNL1Loss=0.901429
# INFO:root:Epoch[1] Batch [0-2700]	Speed: 6.45 samples/sec	RPNAcc=0.995034	RPNLogLoss=0.014425	RPNL1Loss=0.204016	RCNNAcc=0.969757	RCNNLogLoss=0.074352	RCNNL1Loss=0.897393
# INFO:root:Epoch[1] Batch [0-2800]	Speed: 6.37 samples/sec	RPNAcc=0.995205	RPNLogLoss=0.013930	RPNL1Loss=0.204016	RCNNAcc=0.970686	RCNNLogLoss=0.072131	RCNNL1Loss=0.893152
# INFO:root:Epoch[1] Batch [0-2900]	Speed: 7.14 samples/sec	RPNAcc=0.995358	RPNLogLoss=0.013477	RPNL1Loss=0.204016	RCNNAcc=0.971594	RCNNLogLoss=0.069927	RCNNL1Loss=0.891341
# INFO:root:Epoch[1] Batch [0-3000]	Speed: 7.12 samples/sec	RPNAcc=0.995477	RPNLogLoss=0.013141	RPNL1Loss=0.202919	RCNNAcc=0.972452	RCNNLogLoss=0.067883	RCNNL1Loss=0.882906
# INFO:root:Epoch[1] Batch [0-3100]	Speed: 4.71 samples/sec	RPNAcc=0.995292	RPNLogLoss=0.013543	RPNL1Loss=0.206928	RCNNAcc=0.972824	RCNNLogLoss=0.067082	RCNNL1Loss=0.861027
# INFO:root:Epoch[1] Batch [0-3200]	Speed: 7.72 samples/sec	RPNAcc=0.995354	RPNLogLoss=0.013379	RPNL1Loss=0.210666	RCNNAcc=0.973517	RCNNLogLoss=0.065383	RCNNL1Loss=0.861316
# INFO:root:Epoch[1] Batch [0-3300]	Speed: 7.64 samples/sec	RPNAcc=0.995426	RPNLogLoss=0.013149	RPNL1Loss=0.210915	RCNNAcc=0.974077	RCNNLogLoss=0.064081	RCNNL1Loss=0.868421
# INFO:root:Epoch[1] Batch [0-3400]	Speed: 7.65 samples/sec	RPNAcc=0.995472	RPNLogLoss=0.013005	RPNL1Loss=0.211775	RCNNAcc=0.974665	RCNNLogLoss=0.062753	RCNNL1Loss=0.871170
# INFO:root:Epoch[1] Batch [0-3500]	Speed: 7.57 samples/sec	RPNAcc=0.995519	RPNLogLoss=0.012842	RPNL1Loss=0.212046	RCNNAcc=0.975239	RCNNLogLoss=0.061448	RCNNL1Loss=0.873619
# INFO:root:Epoch[1] Batch [0-3600]	Speed: 2.82 samples/sec	RPNAcc=0.995531	RPNLogLoss=0.012836	RPNL1Loss=0.211513	RCNNAcc=0.974406	RCNNLogLoss=0.063383	RCNNL1Loss=0.877337
# INFO:root:Epoch[1] Batch [0-3700]	Speed: 3.67 samples/sec	RPNAcc=0.995418	RPNLogLoss=0.013045	RPNL1Loss=0.211288	RCNNAcc=0.974158	RCNNLogLoss=0.064038	RCNNL1Loss=0.883470
# INFO:root:Epoch[1] Batch [0-3800]	Speed: 1.89 samples/sec	RPNAcc=0.995246	RPNLogLoss=0.013519	RPNL1Loss=0.209380	RCNNAcc=0.972532	RCNNLogLoss=0.067687	RCNNL1Loss=0.892456
# INFO:root:Epoch[1] Batch [0-3900]	Speed: 2.64 samples/sec	RPNAcc=0.995214	RPNLogLoss=0.013569	RPNL1Loss=0.206105	RCNNAcc=0.971576	RCNNLogLoss=0.069779	RCNNL1Loss=0.895151
# INFO:root:Epoch[1] Batch [0-4000]	Speed: 2.11 samples/sec	RPNAcc=0.995104	RPNLogLoss=0.013951	RPNL1Loss=0.207584	RCNNAcc=0.970306	RCNNLogLoss=0.072878	RCNNL1Loss=0.903723
# INFO:root:Epoch[1] Batch [0-4100]	Speed: 3.29 samples/sec	RPNAcc=0.995091	RPNLogLoss=0.014045	RPNL1Loss=0.204931	RCNNAcc=0.969811	RCNNLogLoss=0.074166	RCNNL1Loss=0.899470
# INFO:root:Epoch[1] Batch [0-4200]	Speed: 3.01 samples/sec	RPNAcc=0.995021	RPNLogLoss=0.014335	RPNL1Loss=0.201807	RCNNAcc=0.969029	RCNNLogLoss=0.075951	RCNNL1Loss=0.900282
# INFO:root:Epoch[1] Batch [0-4300]	Speed: 1.87 samples/sec	RPNAcc=0.994854	RPNLogLoss=0.014905	RPNL1Loss=0.195132	RCNNAcc=0.967911	RCNNLogLoss=0.078461	RCNNL1Loss=0.902444
# INFO:root:Epoch[1] Batch [0-4400]	Speed: 1.93 samples/sec	RPNAcc=0.994803	RPNLogLoss=0.015080	RPNL1Loss=0.190062	RCNNAcc=0.967151	RCNNLogLoss=0.080164	RCNNL1Loss=0.904041
# INFO:root:Epoch[1] Batch [0-4500]	Speed: 3.15 samples/sec	RPNAcc=0.994848	RPNLogLoss=0.015074	RPNL1Loss=0.188087	RCNNAcc=0.966929	RCNNLogLoss=0.080925	RCNNL1Loss=0.897564
# INFO:root:Epoch[1] Batch [0-4600]	Speed: 5.45 samples/sec	RPNAcc=0.994892	RPNLogLoss=0.014950	RPNL1Loss=0.187108	RCNNAcc=0.967337	RCNNLogLoss=0.080052	RCNNL1Loss=0.888299
# INFO:root:Epoch[1] Batch [0-4700]	Speed: 5.12 samples/sec	RPNAcc=0.994980	RPNLogLoss=0.014725	RPNL1Loss=0.186181	RCNNAcc=0.967617	RCNNLogLoss=0.079511	RCNNL1Loss=0.876933
# INFO:root:Epoch[1] Train-RPNAcc=0.994982
# INFO:root:Epoch[1] Train-RPNLogLoss=0.014720
# INFO:root:Epoch[1] Train-RPNL1Loss=0.186177
# INFO:root:Epoch[1] Train-RCNNAcc=0.967617
# INFO:root:Epoch[1] Train-RCNNLogLoss=0.079510
# INFO:root:Epoch[1] Train-RCNNL1Loss=0.876678
# INFO:root:Epoch[1] Time cost=2422.913
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0002.params"

# %% [markdown]
# # Running Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from infer_base import *

# %%
class_file = set_class_list("./ir_dataset/annotations/classes.txt");

# %%
#Model - Select the model as per number of iterations it has been trained for

# %%
set_model_params(model_name="vgg16", model_path="trained_model/model_vgg16-0002.params");

# %%
#Hyper Params

# %%
set_hyper_params(gpus="0", batch_size=1);

# %%
# Preprocessing

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
#Initalization

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
#Network

# %%
sym = set_network();
mod = load_model(sym);

# %%
#Load Image and infer

# %%
set_output_params(vis_thresh=0.9, vis=True)
output = Infer("Monk_Object_Detection/example_notebooks/sample_dataset/ir_dataset_test/1.jpg", mod);
# Out:
# person
#  0.9942793846130371 [140.07286458333334, 99.70341796875, 161.80848958333334, 150.84588541666668]
# ['person\n', 0.9942793846130371, [140.07286458333334, 99.70341796875, 161.80848958333334, 150.84588541666668]]

# %%
set_output_params(vis_thresh=0.9, vis=True)
output = Infer("Monk_Object_Detection/example_notebooks/sample_dataset/ir_dataset_test/2.jpg", mod);
# Out:
# person
#  0.9891431927680969 [119.04485677083333, 98.44919270833333, 140.2752734375, 136.47752604166666]
# person
#  0.9074171781539917 [174.15869791666665, 101.44493489583333, 195.16669270833333, 137.69368489583334]
# ['person\n', 0.9891431927680969, [119.04485677083333, 98.44919270833333, 140.2752734375, 136.47752604166666]]
