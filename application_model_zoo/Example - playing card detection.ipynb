# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/3_mxrcnn/Example%20-%20playing%20card%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## 1. Installattion Instructions
#
#
#
# ## 2. Use trained model to detect playing cards in images
#
#
#
# ## 3. How to train using playing cards dataset

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/3_mxrcnn/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/3_mxrcnn/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install


# For Local systems and cloud select the right CUDA version
#! cd Monk_Object_Detection/3_mxrcnn/installation && cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# # Use already trained model for demo

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from infer_base import *

# %%
# Download trained model

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1TBG8ItJ6608D68iFrUhcN7koehXD3QBg' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1TBG8ItJ6608D68iFrUhcN7koehXD3QBg" -O cards_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq cards_trained.zip

# %%
class_file = set_class_list("cards_trained/classes.txt");

# %%
#Model - Select the model as per number of iterations it has been trained for

# %%
set_model_params(model_name="vgg16", model_path="cards_trained/model_vgg16-0100.params");

# %%
#Hyper Params

# %%
set_hyper_params(gpus="0", batch_size=1);

# %%
# Preprocessing

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
#Initalization

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
#Network

# %%
sym = set_network();
mod = load_model(sym);

# %%
#Load Image and infer

# %%
set_output_params(vis_thresh=0.55, vis=True)
Infer("Monk_Object_Detection/example_notebooks/sample_dataset/card_test/img3.jpeg", mod);
# Out:
# ace
#  0.8718158602714539 [158.7199678141266, 69.0989550367659, 345.984230358894, 494.7952712629722]
# ace
#  0.7980578541755676 [267.523600219841, 282.08966208425085, 348.85858978457736, 420.08100782016146]
# ace
#  0.5744339227676392 [55.608631274179814, 106.58873853647673, 120.66113807236792, 305.19369358042695]
# ace
#  0.5640605688095093 [0.0, 105.77573486886772, 251.5809255593912, 236.1204412625771]
# ['ace\n', 0.8718158602714539, [158.7199678141266, 69.0989550367659, 345.984230358894, 494.7952712629722]]

# %%
set_output_params(vis_thresh=0.8, vis=True)
Infer("Monk_Object_Detection/example_notebooks/sample_dataset/card_test/img5.jpeg", mod);
# Out:
# ace
#  0.9751833081245422 [203.21107177734376, 273.491845703125, 442.86396484375, 464.9671875]
# ace
#  0.8952645063400269 [216.4713134765625, 270.329345703125, 274.9453857421875, 477.82841796875]
# ['ace\n', 0.9751833081245422, [203.21107177734376, 273.491845703125, 442.86396484375, 464.9671875]]

# %% [markdown]
# # Train you own detector

# %% [markdown]
# # Download Dataset
#
# - credits: https://www.kaggle.com/luantm/playing-card
#
# - Install kaggle client using: https://github.com/Kaggle/kaggle-api
#     - CMD: `pip install -U kaggle`

# %%
! kaggle datasets download -d luantm/playing-card -q
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/abhi/.kaggle/kaggle.json'

# %%
! unzip -qq playing-card.zip

# %% [markdown]
# # VOC Format
#
# ## Dataset Directory Structure (Non-Standard)
#
#       card_dataset     (root_dir)
#           |
#           |-----------Images+Annotations (img_dir + anno_dir)
#           |              |
#           |              |------------------img1.jpg
#           |              |------------------img1.xml
#           |              |------------------img2.jpg
#           |              |------------------img2.xml
#           |              |------------------.........(and so on)

# %% [markdown]
# # Desired annotation - COCO Format
#
# ## Dataset Directory Structure
#
#     ./ (root_dir)
#           |
#           |------card_dataset (coco_dir)
#           |         |
#           |         |---Images (img_dir)
#           |         |----|
#           |              |-------------------img1.jpg
#           |              |-------------------img2.jpg
#           |              |-------------------.........(and so on)
#           |
#           |
#           |         |---annotations (anno_dir)
#           |         |----|
#           |              |--------------------instances_Images.json
#           |              |--------------------classes.txt
#
#
#  - instances_Train.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order

# %% [markdown]
# # Annotation Conversion - Step 1 - VOC to Monk format

# %%
import os
import sys
import numpy as np
import pandas as pd

import xmltodict
import json
from tqdm.notebook import tqdm

from pycocotools.coco import COCO

# %%
root_dir = "card_dataset/";
img_dir = "train/";
anno_dir = "train/";

# %%
files_tmp = os.listdir(root_dir + anno_dir);
files = [];
for i in range(len(files_tmp)):
    ext = files_tmp[i].split(".")[-1];
    if(ext == "xml"):
        files.append(files_tmp[i])

# %%
combined = [];
for i in tqdm(range(len(files))):
    annoFile = root_dir + "/" + anno_dir + "/" + files[i];
    f = open(annoFile, 'r');
    my_xml = f.read();
    anno = dict(dict(xmltodict.parse(my_xml))["annotation"])
    fname = anno["filename"];
    label_str = "";
    if(type(anno["object"]) == list):
        for j in range(len(anno["object"])):
            obj = dict(anno["object"][j]);
            label = anno["object"][j]["name"];
            bbox = dict(anno["object"][j]["bndbox"])
            x1 = bbox["xmin"];
            y1 = bbox["ymin"];
            x2 = bbox["xmax"];
            y2 = bbox["ymax"];
            if(j == len(anno["object"])-1):
                label_str += x1 + " " + y1 + " " + x2 + " " + y2 + " " + label;
            else:        
                label_str += x1 + " " + y1 + " " + x2 + " " + y2 + " " + label + " ";
    else:
        obj = dict(anno["object"]);
        label = anno["object"]["name"];
        bbox = dict(anno["object"]["bndbox"])
        x1 = bbox["xmin"];
        y1 = bbox["ymin"];
        x2 = bbox["xmax"];
        y2 = bbox["ymax"];
        
        label_str += x1 + " " + y1 + " " + x2 + " " + y2 + " " + label;
    
    
    combined.append([fname, label_str])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=296.0), HTML(value='')))

# %%
df = pd.DataFrame(combined, columns = ['ID', 'Label']);
df.to_csv(root_dir + "/train_labels.csv", index=False);

# %% [markdown]
# # Annotation Conversion - Step 1 - Monk format to COCO

# %%
import os
import numpy as np 
import cv2
import dicttoxml
import xml.etree.ElementTree as ET
from xml.dom.minidom import parseString
from tqdm import tqdm
import shutil
import json
import pandas as pd

# %%
# Provide details on directory in Monk Format

# %%
root = "card_dataset";
img_dir = "train/";
anno_file = "train_labels.csv";

# %%
# Need not change anything below

# %%
dataset_path = root;
images_folder = root + "/" + img_dir;
annotations_path = root + "/annotations/";

# %%
if not os.path.isdir(annotations_path):
    os.mkdir(annotations_path)
    
input_images_folder = images_folder;
input_annotations_path = root + "/" + anno_file;

# %%
output_dataset_path = root;
output_image_folder = input_images_folder;
output_annotation_folder = annotations_path;

tmp = img_dir.replace("/", "");
output_annotation_file = output_annotation_folder + "/instances_" + tmp + ".json";
output_classes_file = output_annotation_folder + "/classes.txt";

# %%
if not os.path.isdir(output_annotation_folder):
    os.mkdir(output_annotation_folder);

# %%
df = pd.read_csv(input_annotations_path);
columns = df.columns

# %%
delimiter = " ";

# %%
list_dict = [];
anno = [];
for i in range(len(df)):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    for j in range(len(tmp)//5):
        label = tmp[j*5+4];
        if(label not in anno):
            anno.append(label);
    anno = sorted(anno)
    
for i in tqdm(range(len(anno))):
    tmp = {};
    tmp["supercategory"] = "master";
    tmp["id"] = i;
    tmp["name"] = anno[i];
    list_dict.append(tmp);

anno_f = open(output_classes_file, 'w');
for i in range(len(anno)):
    anno_f.write(anno[i] + "\n");
anno_f.close();
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 14035.60it/s]

# %%
coco_data = {};
coco_data["type"] = "instances";
coco_data["images"] = [];
coco_data["annotations"] = [];
coco_data["categories"] = list_dict;
image_id = 0;
annotation_id = 0;


for i in tqdm(range(len(df))):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    image_in_path = input_images_folder + "/" + img_name;
    img = cv2.imread(image_in_path, 1);
    h, w, c = img.shape;

    images_tmp = {};
    images_tmp["file_name"] = img_name;
    images_tmp["height"] = h;
    images_tmp["width"] = w;
    images_tmp["id"] = image_id;
    coco_data["images"].append(images_tmp);
    

    for j in range(len(tmp)//5):
        x1 = int(tmp[j*5+0]);
        y1 = int(tmp[j*5+1]);
        x2 = int(tmp[j*5+2]);
        y2 = int(tmp[j*5+3]);
        label = tmp[j*5+4];
        annotations_tmp = {};
        annotations_tmp["id"] = annotation_id;
        annotation_id += 1;
        annotations_tmp["image_id"] = image_id;
        annotations_tmp["segmentation"] = [];
        annotations_tmp["ignore"] = 0;
        annotations_tmp["area"] = (x2-x1)*(y2-y1);
        annotations_tmp["iscrowd"] = 0;
        annotations_tmp["bbox"] = [x1, y1, x2-x1, y2-y1];
        annotations_tmp["category_id"] = anno.index(label);

        coco_data["annotations"].append(annotations_tmp)
    image_id += 1;

outfile =  open(output_annotation_file, 'w');
json_str = json.dumps(coco_data, indent=4);
outfile.write(json_str);
outfile.close();
# Out:
# 100%|██████████| 296/296 [00:01<00:00, 202.13it/s]

# %% [markdown]
# # Training

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from train_base import *

# %%
# Dataset params

# %%
root_dir = "./";
coco_dir = "card_dataset";
img_dir = "train";

# %%
set_dataset_params(root_dir=root_dir, 
                   coco_dir=coco_dir, imageset=img_dir);

# %%
# Model Type

# %%
set_model_params(model_name="vgg16");

# %%
# Hyper Params

# %%
set_hyper_params(gpus="0", lr=0.001, lr_decay_epoch="1", epochs=4, batch_size=1);

# %%
set_output_params(log_interval=100, save_prefix="model_vgg16");

# %%
# Preprocessing params

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
# Initialize params

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
# Remove caches if any

# %%
if os.path.isdir("./cache/"):
    os.system("rm -r ./cache/")

# %%
# Invoke Dataloader

# %%
roidb = set_dataset();
# Out:
# INFO:root:computing cache ./cache/coco_train_roidb.pkl
# INFO:root:saving cache ./cache/coco_train_roidb.pkl
# INFO:root:coco_train num_images 296
# INFO:root:filter roidb: 296 -> 296
# INFO:root:coco_train append flipped images to roidb
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
#Network

# %%
sym = set_network();

# %%
# Train

# %%
train(sym, roidb);
# Out:
# INFO:root:max input shape
# {'bbox_target': (1, 36, 62, 62),
#  'bbox_weight': (1, 36, 62, 62),
#  'data': (1, 3, 1000, 1000),
#  'gt_boxes': (1, 100, 5),
#  'im_info': (1, 3),
#  'label': (1, 1, 558, 62)}
# INFO:root:max output shape
# {'bbox_loss_reshape_output': (1, 128, 28),
#  'blockgrad0_output': (1, 128),
#  'cls_prob_reshape_output': (1, 128, 7),
#  'rpn_bbox_loss_output': (1, 36, 62, 62),
#  'rpn_cls_prob_output': (1, 2, 558, 62)}
# INFO:root:locking params
# ['conv1_1_weight',
#  'conv1_1_bias',
#  'conv1_2_weight',
#  'conv1_2_bias',
#  'conv2_1_weight',
#  'conv2_1_bias',
#  'conv2_2_weight',
#  'conv2_2_bias',
#  'conv3_1_weight',
#  'conv3_1_bias',
#  'conv3_2_weight',
#  'conv3_2_bias',
#  'conv3_3_weight',
#  'conv3_3_bias',
#  'conv4_1_weight',
#  'conv4_1_bias',
#  'conv4_2_weight',
#  'conv4_2_bias',
#  'conv4_3_weight',
#  'conv4_3_bias']
# INFO:root:lr 0.001000 lr_epoch_diff [1] lr_iters [592]
# INFO:root:Epoch[0] Batch [0-100]	Speed: 4.64 samples/sec	RPNAcc=0.947788	RPNLogLoss=0.172843	RPNL1Loss=0.802413	RCNNAcc=0.788598	RCNNLogLoss=0.669276	RCNNL1Loss=2.520975
# INFO:root:Epoch[0] Batch [0-200]	Speed: 4.57 samples/sec	RPNAcc=0.964222	RPNLogLoss=0.118908	RPNL1Loss=0.643752	RCNNAcc=0.805037	RCNNLogLoss=0.572884	RCNNL1Loss=2.354682
# INFO:root:Epoch[0] Batch [0-300]	Speed: 4.70 samples/sec	RPNAcc=0.970697	RPNLogLoss=0.095093	RPNL1Loss=0.583153	RCNNAcc=0.817457	RCNNLogLoss=0.513669	RCNNL1Loss=2.126801
# INFO:root:Epoch[0] Batch [0-400]	Speed: 4.63 samples/sec	RPNAcc=0.974137	RPNLogLoss=0.083444	RPNL1Loss=0.525346	RCNNAcc=0.825592	RCNNLogLoss=0.482350	RCNNL1Loss=1.929237
# INFO:root:Epoch[0] Batch [0-500]	Speed: 4.53 samples/sec	RPNAcc=0.976282	RPNLogLoss=0.076270	RPNL1Loss=0.490989	RCNNAcc=0.836468	RCNNLogLoss=0.445896	RCNNL1Loss=1.781985
# INFO:root:Epoch[0] Train-RPNAcc=0.977737
# INFO:root:Epoch[0] Train-RPNLogLoss=0.070549
# INFO:root:Epoch[0] Train-RPNL1Loss=0.474353
# INFO:root:Epoch[0] Train-RCNNAcc=0.843605
# INFO:root:Epoch[0] Train-RCNNLogLoss=0.422195
# INFO:root:Epoch[0] Train-RCNNL1Loss=1.686727
# INFO:root:Epoch[0] Time cost=128.974
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0001.params"
# INFO:root:Update[593]: Change learning rate to 1.00000e-04
# INFO:root:Epoch[1] Batch [0-100]	Speed: 4.65 samples/sec	RPNAcc=0.988127	RPNLogLoss=0.034835	RPNL1Loss=0.290305	RCNNAcc=0.892791	RCNNLogLoss=0.284278	RCNNL1Loss=1.046518
# INFO:root:Epoch[1] Batch [0-200]	Speed: 4.53 samples/sec	RPNAcc=0.987931	RPNLogLoss=0.036629	RPNL1Loss=0.275820	RCNNAcc=0.903451	RCNNLogLoss=0.253488	RCNNL1Loss=0.945842
# INFO:root:Epoch[1] Batch [0-300]	Speed: 4.70 samples/sec	RPNAcc=0.988852	RPNLogLoss=0.033072	RPNL1Loss=0.264682	RCNNAcc=0.912401	RCNNLogLoss=0.232137	RCNNL1Loss=0.878340
# INFO:root:Epoch[1] Batch [0-400]	Speed: 4.62 samples/sec	RPNAcc=0.988759	RPNLogLoss=0.033140	RPNL1Loss=0.260710	RCNNAcc=0.913868	RCNNLogLoss=0.227011	RCNNL1Loss=0.851641
# INFO:root:Epoch[1] Batch [0-500]	Speed: 4.51 samples/sec	RPNAcc=0.988765	RPNLogLoss=0.032842	RPNL1Loss=0.254796	RCNNAcc=0.917306	RCNNLogLoss=0.217342	RCNNL1Loss=0.819700
# INFO:root:Epoch[1] Train-RPNAcc=0.989278
# INFO:root:Epoch[1] Train-RPNLogLoss=0.031219
# INFO:root:Epoch[1] Train-RPNL1Loss=0.248734
# INFO:root:Epoch[1] Train-RCNNAcc=0.920476
# INFO:root:Epoch[1] Train-RCNNLogLoss=0.209286
# INFO:root:Epoch[1] Train-RCNNL1Loss=0.799508
# INFO:root:Epoch[1] Time cost=128.382
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0002.params"
# INFO:root:Epoch[2] Batch [0-100]	Speed: 4.65 samples/sec	RPNAcc=0.989364	RPNLogLoss=0.031127	RPNL1Loss=0.225640	RCNNAcc=0.932085	RCNNLogLoss=0.181877	RCNNL1Loss=0.772461
# INFO:root:Epoch[2] Batch [0-200]	Speed: 4.55 samples/sec	RPNAcc=0.988903	RPNLogLoss=0.032558	RPNL1Loss=0.218310	RCNNAcc=0.935479	RCNNLogLoss=0.176122	RCNNL1Loss=0.725317
# INFO:root:Epoch[2] Batch [0-300]	Speed: 4.70 samples/sec	RPNAcc=0.989735	RPNLogLoss=0.029309	RPNL1Loss=0.213882	RCNNAcc=0.938253	RCNNLogLoss=0.168366	RCNNL1Loss=0.695809
# INFO:root:Epoch[2] Batch [0-400]	Speed: 4.62 samples/sec	RPNAcc=0.989665	RPNLogLoss=0.029461	RPNL1Loss=0.214426	RCNNAcc=0.938591	RCNNLogLoss=0.168324	RCNNL1Loss=0.698331
# INFO:root:Epoch[2] Batch [0-500]	Speed: 4.52 samples/sec	RPNAcc=0.989583	RPNLogLoss=0.029440	RPNL1Loss=0.213003	RCNNAcc=0.939543	RCNNLogLoss=0.165249	RCNNL1Loss=0.681885
# INFO:root:Epoch[2] Train-RPNAcc=0.990089
# INFO:root:Epoch[2] Train-RPNLogLoss=0.028088
# INFO:root:Epoch[2] Train-RPNL1Loss=0.209222
# INFO:root:Epoch[2] Train-RCNNAcc=0.941763
# INFO:root:Epoch[2] Train-RCNNLogLoss=0.160154
# INFO:root:Epoch[2] Train-RCNNL1Loss=0.667990
# INFO:root:Epoch[2] Time cost=128.215
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0003.params"
# INFO:root:Epoch[3] Batch [0-100]	Speed: 4.66 samples/sec	RPNAcc=0.990060	RPNLogLoss=0.029897	RPNL1Loss=0.206784	RCNNAcc=0.946395	RCNNLogLoss=0.151714	RCNNL1Loss=0.697356
# INFO:root:Epoch[3] Batch [0-200]	Speed: 4.55 samples/sec	RPNAcc=0.989000	RPNLogLoss=0.030792	RPNL1Loss=0.200147	RCNNAcc=0.944807	RCNNLogLoss=0.153004	RCNNL1Loss=0.656898
# INFO:root:Epoch[3] Batch [0-300]	Speed: 4.71 samples/sec	RPNAcc=0.989735	RPNLogLoss=0.027678	RPNL1Loss=0.196974	RCNNAcc=0.947467	RCNNLogLoss=0.146589	RCNNL1Loss=0.630084
# INFO:root:Epoch[3] Batch [0-400]	Speed: 4.62 samples/sec	RPNAcc=0.989781	RPNLogLoss=0.027905	RPNL1Loss=0.198062	RCNNAcc=0.947982	RCNNLogLoss=0.146145	RCNNL1Loss=0.631866
# INFO:root:Epoch[3] Batch [0-500]	Speed: 4.51 samples/sec	RPNAcc=0.989778	RPNLogLoss=0.027885	RPNL1Loss=0.197576	RCNNAcc=0.948759	RCNNLogLoss=0.143362	RCNNL1Loss=0.618218
# INFO:root:Epoch[3] Train-RPNAcc=0.990168
# INFO:root:Epoch[3] Train-RPNLogLoss=0.026696
# INFO:root:Epoch[3] Train-RPNL1Loss=0.194113
# INFO:root:Epoch[3] Train-RCNNAcc=0.950209
# INFO:root:Epoch[3] Train-RCNNLogLoss=0.139080
# INFO:root:Epoch[3] Train-RCNNL1Loss=0.606780
# INFO:root:Epoch[3] Time cost=128.229
# INFO:root:Saved checkpoint to "trained_model/model_vgg16-0004.params"

# %% [markdown]
# # Running Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/")
sys.path.append("Monk_Object_Detection/3_mxrcnn/lib/mx-rcnn")

# %%
from infer_base import *

# %%
class_file = set_class_list("./card_dataset/annotations/classes.txt");

# %%
#Model - Select the model as per number of iterations it has been trained for

# %%
set_model_params(model_name="vgg16", model_path="trained_model/model_vgg16-0004.params");

# %%
#Hyper Params

# %%
set_hyper_params(gpus="0", batch_size=1);

# %%
# Preprocessing

# %%
set_img_preproc_params(img_short_side=600, img_long_side=1000, 
                       mean=(123.68, 116.779, 103.939), std=(1.0, 1.0, 1.0));

# %%
#Initalization

# %%
initialize_rpn_params();

# %%
initialize_rcnn_params();

# %%
#Network

# %%
sym = set_network();
mod = load_model(sym);

# %%
#Load Image and infer

# %%
set_output_params(vis_thresh=0.55, vis=True)
Infer("Monk_Object_Detection/example_notebooks/sample_dataset/card_test/img3.jpeg", mod);
# Out:
# ace
#  0.9597503542900085 [148.3417018999005, 83.90620404263191, 382.8754715625595, 492.99056336055]
# ace
#  0.5799654722213745 [59.18078618306434, 109.41343975745646, 129.82747940786615, 437.7891236174623]
# ['ace\n', 0.9597503542900085, [148.3417018999005, 83.90620404263191, 382.8754715625595, 492.99056336055]]

# %%
set_output_params(vis_thresh=0.9, vis=True)
Infer("Monk_Object_Detection/example_notebooks/sample_dataset/card_test/img5.jpeg", mod);
# Out:
# ace
#  0.9895508885383606 [196.94495849609376, 292.27158203125, 431.86494140625, 473.400048828125]
# ['ace\n', 0.9895508885383606, [196.94495849609376, 292.27158203125, 431.86494140625, 473.400048828125]]

# %%
set_output_params(vis_thresh=0.55, vis=True)
Infer("Monk_Object_Detection/example_notebooks/sample_dataset/card_test/img11.jpeg", mod);
# Out:
# ace
#  0.9289224147796631 [23.672652995008743, 216.86185814360186, 159.01728191825262, 331.73778724091596]
# ace
#  0.7662843465805054 [312.3098840312007, 231.7871012093419, 422.2544472536303, 328.6251831889669]
# ace
#  0.5554117560386658 [446.8487556346718, 215.41299718352187, 556.4316610358804, 316.7091683251694]
# nine
#  0.7482169270515442 [180.59866849399623, 224.7483319224843, 277.5690895792069, 324.0098681426535]
# ['ace\n', 0.9289224147796631, [23.672652995008743, 216.86185814360186, 159.01728191825262, 331.73778724091596]]
