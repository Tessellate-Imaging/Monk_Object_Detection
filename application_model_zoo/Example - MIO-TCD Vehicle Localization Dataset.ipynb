# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/application_model_zoo/Example%20-%20MIO-TCD%20Vehicle%20Localization%20Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table of contents
#
#
# ## 1. Installation Instructions
#
#
#
# ## 2. Use trained model to detect vehicles
#
#
#
# ## 3. How to train using MMdetection wrapper

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/16_mmdet/installation
#
#  - Select the right file and run
#
#      - chmod +x install.sh && ./install.sh

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
! cd Monk_Object_Detection/16_mmdet/installation && chmod +x install.sh && ./install.sh

# %% [markdown]
# # Use already trained model for demo

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/16_mmdet/lib")

# %%
from infer_engine import Infer

# %%
gtf = Infer();

# %%
# Download trained model

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1GdcZS9EKdrNS1v5CLWqhOdiAuHZWONFp' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1GdcZS9EKdrNS1v5CLWqhOdiAuHZWONFp" -O obj_miotcd_trained.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq obj_miotcd_trained.zip

# %%
gtf.Model_Params("work_dirs/config_updated/config_updated.py", 
                 "work_dirs/config_updated/latest.pth")

# %%
! cp MIO-TCD-Localization/train/00110523.jpg work_dirs/test/10.jpg

# %%
result = gtf.Predict(img_path="work_dirs/test/1.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.06935262680053711 sec
# Saving Time: 0.012002706527709961 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/2.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.07496404647827148 sec
# Saving Time: 0.011436223983764648 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/3.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.07572293281555176 sec
# Saving Time: 0.011202335357666016 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/4.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.0691382884979248 sec
# Saving Time: 0.011386871337890625 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/5.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.06818151473999023 sec
# Saving Time: 0.010567665100097656 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/6.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.07351946830749512 sec
# Saving Time: 0.010696172714233398 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/7.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.068206787109375 sec
# Saving Time: 0.011360883712768555 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/8.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.06991028785705566 sec
# Saving Time: 0.010842561721801758 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/9.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.07230615615844727 sec
# Saving Time: 0.011068582534790039 sec

# %%
result = gtf.Predict(img_path="work_dirs/test/10.jpg",
           out_img_path="result.jpg",
           thresh=0.3, bbox_color='red', text_color='red', thickness=2, font_scale=0.5);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
# Out:
# Inference Time: 0.07691788673400879 sec
# Saving Time: 0.0035736560821533203 sec

# %% [markdown]
# # Training your own detector

# %% [markdown]
# ## Dataset
#  - Credits: http://podoce.dinf.usherbrooke.ca/challenge/dataset/

# %%
! wget http://podoce.dinf.usherbrooke.ca/static/dataset/MIO-TCD-Localization.tar

# %%
! tar -xvf MIO-TCD-Localization.tar

# %% [markdown]
# # Data Conversion from current format to COCO Format

# %% [markdown]
# # Current Format
#
# ## Dataset Directory Structure
#
#        Dataset (root_dir)
#           |
#           |-----------Images (img_dir)
#           |              |
#           |              |------------------img1.jpg
#           |              |------------------img2.jpg
#           |              |------------------.........(and so on)
#           |
#           |
#           |-----------Annotations (anno_dir)
#           |              |
#           |              |------------------img1.xml
#           |              |------------------img2.xml
#           |              |------------------.........(and so on)

# %% [markdown]
# # COCO Format
#
# ## Dataset Directory Structure
#
#        Dataset (root_dir)
#           |
#           |
#           |
#           |---Images (img_dir)
#           |----|
#                |-------------------img1.jpg
#                |-------------------img2.jpg
#                |-------------------.........(and so on)
#
#
#           |---annotations (anno_dir)
#           |----|
#                |--------------------instances_Images.json
#                |--------------------classes.txt
#
#
#  - instances_Images.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order

# %%
import numpy as np
import pandas as pd

f = open("MIO-TCD-Localization/gt_train.csv");
lines = f.readlines();
f.close();

current_image = lines[0].split(",")[0]
wr = "";
combined = [];

for i in range(len(lines)):
    tmp = lines[i][:len(lines[i])-1].split(",");

    img_name = tmp[0];
    label = tmp[1];
    x1 = tmp[2];
    y1 = tmp[3];
    x2 = tmp[4];
    y2 = tmp[5];

    if(img_name != current_image):
        wr = wr[:len(wr)-1];
        combined.append([str(current_image) + ".jpg", wr]);
        wr = "";

        current_image = img_name;
    
    wr += x1 + " " + y1 + " " + x2 + " " + y2 + " " + label + " ";



df = pd.DataFrame(combined, columns = ['ID', 'Label'])
df.to_csv("train_labels.csv", index=False);
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5720.0), HTML(value='')))

# %%
! pip install dicttoxml

# %%
import os
import numpy as np 
import cv2
import dicttoxml
import xml.etree.ElementTree as ET
from xml.dom.minidom import parseString
from tqdm import tqdm
import shutil
import json
import pandas as pd
from tqdm import tqdm

root = "./";
img_dir = "MIO-TCD-Localization/train/";
anno_file = "train_labels.csv";



dataset_path = root;
images_folder = root + "/" + img_dir;
annotations_path = root + "/annotations/";


if not os.path.isdir(annotations_path):
    os.mkdir(annotations_path)
    
input_images_folder = images_folder;
input_annotations_path = root + "/" + anno_file;



output_dataset_path = root;
output_image_folder = input_images_folder;
output_annotation_folder = annotations_path;

tmp = img_dir.replace("/", "");
output_annotation_file = output_annotation_folder + "/instances_" + tmp + ".json";
output_classes_file = output_annotation_folder + "/classes.txt";



if not os.path.isdir(output_annotation_folder):
    os.mkdir(output_annotation_folder);

df = pd.read_csv(input_annotations_path);
columns = df.columns

delimiter = " ";


list_dict = [];
anno = [];
for i in tqdm(range(len(df))):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    for j in range(len(tmp)//5):
        label = tmp[j*5+4];
        if(label not in anno):
            anno.append(label);
    anno = sorted(anno)
    
for i in tqdm(range(len(anno))):
    tmp = {};
    tmp["supercategory"] = "master";
    tmp["id"] = i;
    tmp["name"] = anno[i];
    list_dict.append(tmp);

anno_f = open(output_classes_file, 'w');
for i in range(len(anno)):
    anno_f.write(anno[i] + "\n");
anno_f.close();
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 5363.56it/s]
#   1%|          | 50/5720 [00:00<00:11, 492.35it/s]
# ['trash']
# 100%|██████████| 5720/5720 [00:11<00:00, 487.98it/s]

# %%
coco_data = {};
coco_data["type"] = "instances";
coco_data["images"] = [];
coco_data["annotations"] = [];
coco_data["categories"] = list_dict;
image_id = 0;
annotation_id = 0;


for i in tqdm(range(len(df))):
    img_name = df[columns[0]][i];
    labels = df[columns[1]][i];
    tmp = labels.split(delimiter);
    image_in_path = input_images_folder + "/" + img_name;
    #print(image_in_path)
    img = cv2.imread(image_in_path, 1);
    h, w, c = img.shape;

    images_tmp = {};
    images_tmp["file_name"] = img_name;
    images_tmp["height"] = h;
    images_tmp["width"] = w;
    images_tmp["id"] = image_id;
    coco_data["images"].append(images_tmp);
    

    for j in range(len(tmp)//5):
        x1 = int(tmp[j*5+0]);
        y1 = int(tmp[j*5+1]);
        x2 = int(tmp[j*5+2]);
        y2 = int(tmp[j*5+3]);
        label = tmp[j*5+4];
        annotations_tmp = {};
        annotations_tmp["id"] = annotation_id;
        annotation_id += 1;
        annotations_tmp["image_id"] = image_id;
        annotations_tmp["segmentation"] = [];
        annotations_tmp["ignore"] = 0;
        annotations_tmp["area"] = (x2-x1)*(y2-y1);
        annotations_tmp["iscrowd"] = 0;
        annotations_tmp["bbox"] = [x1, y1, x2-x1, y2-y1];
        annotations_tmp["category_id"] = anno.index(label);

        coco_data["annotations"].append(annotations_tmp)
    image_id += 1;

outfile =  open(output_annotation_file, 'w');
json_str = json.dumps(coco_data, indent=4);
outfile.write(json_str);
outfile.close();
# Out:
# HBox(children=(FloatProgress(value=0.0, max=820.0), HTML(value='')))

# %% [markdown]
# # Training

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/16_mmdet/lib")

# %%
from train_engine import Detector

# %%
gtf = Detector();

# %%
img_dir = "MIO-TCD-Localization/train/";
annofile = "annotations/instances_MIO-TCD-Localizationtrain.json"
class_file = "annotations/classes.txt"

gtf.Train_Dataset(img_dir, annofile, class_file);

# %%
gtf.Val_Dataset(img_dir, annofile);

# %%
gtf.Dataset_Params(batch_size=8, num_workers=4)

# %%
gtf.List_Models();
# Out:
# 1. Model - faster_rcnn_fpn50
# 2. Model - faster_rcnn_fpn101
# 3. Model - faster_rcnn_x101_32x4d_fpn
# 4. Model - faster_rcnn_x101_64x4d_fpn
# 5. Model - cascade_rcnn_fpn50
# 6. Model - cascade_rcnn_fpn101
# 7. Model - cascade_rcnn_x101_32x4d_fpn
# 8. Model - cascade_rcnn_x101_64x4d_fpn
# 9. Model - retinanet_r50_fpn
# 10. Model - retinanet_r101_fpn
# 11. Model - retinanet_x101_32x4d_fpn
# 12. Model - retinanet_x101_64x4d_fpn
# 13. Model - retinanet_ghm_r50_fpn
# 14. Model - retinanet_ghm_r101_fpn
# 15. Model - retinanet_ghm_x101_32x4d_fpn
# 16. Model - retinanet_ghm_x101_64x4d_fpn
# 17. Model - dh_faster_rcnn_fpn50
# 18. Model - libra_faster_rcnn_fpn50
# 19. Model - libra_faster_rcnn_fpn101
# 20. Model - libra_faster_rcnn_x101_64x4d_fpn
# 21. Model - libra_retinanet_r50_fpn
# 22. Model - ga_faster_rcnn_x101_32x4d_fpn
# 23. Model - ga_faster_rcnn_x101_64x4d_fpn
# 24. Model - ga_retinanet_x101_32x4d_fpn
# 25. Model - ga_retinanet_x101_64x4d_fpn
# 26. Model - fovea_r50_fpn_4x4
# 27. Model - fovea_r101_fpn_4x4
# 28. Model - fovea_align_r50_fpn_gn-head_mstrain_640-800_4x4
# 29. Model - fovea_align_r101_fpn_gn-head_mstrain_640-800_4x4
# 30. Model - free_anchor_retinanet_r50_fpn
# 31. Model - free_anchor_retinanet_r101_fpn
# 32. Model - free_anchor_retinanet_x101_32x4d_fpn
# 33. Model - atss_r50_fpn
# 34. Model - pafpn_faster_rcnn_r50
# 35. Model - faster_rcnn_r50_fpn_mdpool
# 36. Model - faster_rcnn_r50_fpn_dpool

# %%
gtf.Model_Params(model_name="retinanet_r50_fpn");

# %%
gtf.Hyper_Params(lr=0.02, momentum=0.9, weight_decay=0.0001);

# %%
gtf.Training_Params(num_epochs=2, val_interval=1);

# %%
gtf.Train();

# %% [markdown]
# # Run inference on images

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/16_mmdet/lib")

# %%
from infer_engine import Infer

# %%
gtf = Infer();

# %%
gtf.Model_Params("work_dirs/config_updated/config_updated.py", 
                 "work_dirs/config_updated/latest.pth")

# %%
import os
img_list = os.listdir("MIO-TCD-Localization/train/");

# %%
result = gtf.Predict(img_path="MIO-TCD-Localization/train/" + img_list[0],
           out_img_path="result.jpg",
           thresh=0.8);

from IPython.display import Image
Image(filename='result.jpg', width=490, height=640)
