# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/7_yolov3/Infer%20using%20pretrained%20models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/7_yolov3/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/7_yolov3/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install

# For Local systems and cloud select the right CUDA version
# ! cd Monk_Object_Detection/7_yolov3/installation && cat requirements.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# # About the network
#
# 1. Paper on Yolov3: https://arxiv.org/abs/1804.02767
#
# 2. Paper on Yolov3-SPP: https://arxiv.org/abs/1903.08589
#
# 3. Darknet: https://pjreddie.com/darknet/
#
# 4. Blog-1 on yolo: https://machinethink.net/blog/object-detection-with-yolo/
#
# 5. Blog-2 on yolo: https://medium.com/@jonathan_hui/real-time-object-detection-with-yolo-yolov2-28b1b93e2088
#
# 6. Blog-3 on yolo: https://blog.ekbana.com/training-yolov2-in-a-custom-dataset-6fcf58f65fa2
#
# 7. Blog-4 on yolo: https://towardsdatascience.com/yolo-v3-object-detection-53fb7d3bfe6b
#
# 8. Blog-5 on yolo: https://blog.insightdatascience.com/how-to-train-your-own-yolov3-detector-from-scratch-224d10e55de2

# %% [markdown]
# # Inference

# %%
import os
import sys
from IPython.display import Image
sys.path.append("Monk_Object_Detection/7_yolov3/lib");

# %%
from infer_detector import Infer

# %%
gtf = Infer();

# %%
#Available model names
model_name="yolov3-spp-ultralytics";
#model_name="yolov3-spp";
#model_name="yolov3-tiny";
#model_name="yolov3";

# %%
# Based on the model selected uncomment the related line
# Run it again is models are not downloaded properly

# yolov3-spp-ultralytics
#! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UcR-zVoMs7DH5dj3N1bswkiQTA4dmKF4' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UcR-zVoMs7DH5dj3N1bswkiQTA4dmKF4" -O yolov3-spp-ultralytics.pt && rm -rf /tmp/cookies.txt

# yolov3-spp
#! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1f6Ovy3BSq2wYq4UfvFUpxJFNDFfrIDcR' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1f6Ovy3BSq2wYq4UfvFUpxJFNDFfrIDcR" -O yolov3-spp.pt && rm -rf /tmp/cookies.txt

#yolov3-tiny
#! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=10m_3MlpQwRtZetQxtksm9jqHrPTHZ6vo' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=10m_3MlpQwRtZetQxtksm9jqHrPTHZ6vo" -O yolov3-tiny.pt && rm -rf /tmp/cookies.txt

#yolov3
#! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1SHNFyoe5Ni8DajDNEqgB2oVKBb_NoEad' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1SHNFyoe5Ni8DajDNEqgB2oVKBb_NoEad" -O yolov3.pt && rm -rf /tmp/cookies.txt

# %%
gtf.Pretrained_Model(model_name, use_gpu=True, input_size=416);
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 980 Ti', total_memory=6082MB)

# %%
img_path = "test.png";
scores, bboxes, labels = gtf.Predict_On_Image(img_path, conf_thresh=0.3, iou_thresh=0.5, output_img_path="output.png", verbose=False);
Image(filename='output.png')

# %%
folder_path = "test_folder";
output = gtf.Predict_On_Folder(folder_path, conf_thresh=0.3, iou_thresh=0.5, output_folder_path="output_folder", verbose=False);
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  4.20it/s]
# Outputs stored at folder - output_folder

# %% [markdown]
# # Download Sample Validation Dataset
#  - Credits: https://pjreddie.com/projects/pascal-voc-dataset-mirror/

# %%
! wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1QvVDAKiuaDIkk8gcSQfFn6eok3pT08zF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1QvVDAKiuaDIkk8gcSQfFn6eok3pT08zF" -O pascal_voc_sample.zip && rm -rf /tmp/cookies.txt

# %%
! unzip -qq pascal_voc_sample.zip

# %%
image_folder = "val/images";
gt_folder = "val/gt";

mAP, ap_dictionary, lamr_dictionary = gtf.Evaluate_On_Folder(image_folder, gt_folder, 
                                                                output_folder_path='eval_result', 
                                                                conf_thresh=0.1,
                                                                iou_thresh=0.5);
# Out:
# ...
#  17%|█▋        | 19/112 [00:00<00:00, 185.37it/s]
# Outputs stored at folder - eval_result
# 100%|██████████| 112/112 [00:00<00:00, 534.51it/s]
# 0.00% = aeroplane AP
# 66.67% = bicycle AP
# 85.71% = bird AP
# 80.00% = boat AP
# 84.55% = bottle AP
# 100.00% = bus AP
# 79.08% = car AP
# 96.97% = cat AP
# 68.16% = chair AP
# 66.67% = cow AP
# 0.00% = diningtable AP
# 75.00% = dog AP
# 97.50% = horse AP
# 0.00% = motorbike AP
# 74.87% = person AP
# 0.00% = pottedplant AP
# 83.33% = sheep AP
# 0.00% = sofa AP
# 76.39% = train AP
# 0.00% = tvmonitor AP
# mAP = 56.74%
