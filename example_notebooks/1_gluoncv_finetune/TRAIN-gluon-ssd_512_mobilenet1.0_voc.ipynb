# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/1_gluoncv_finetune/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install


# For Local systems and cloud select the right CUDA version
# !cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# ## Dataset Directory Structure
#
#     Parent_Directory (root)
#           |
#           |-----------Images (img_dir)
#           |              |
#           |              |------------------img1.jpg
#           |              |------------------img2.jpg
#           |              |------------------.........(and so on)
#           |
#           |
#           |-----------train_labels.csv (anno_file)
#
#
# ## Annotation file format
#
#            | Id         | Labels                                 |
#            | img1.jpg   | x1 y1 x2 y2 label1 x1 y1 x2 y2 label2  |
#
# - Labels:  xmin ymin xmax ymax label
# - xmin, ymin - top left corner of bounding box
# - xmax, ymax - bottom right corner of bounding box

# %% [markdown]
# # About the Network
#
# 1. Blog 1 on MobileNet - https://towardsdatascience.com/review-mobilenetv1-depthwise-separable-convolution-light-weight-model-a382df364b69
#
# 2. Blog 2 on MobileNet - https://machinethink.net/blog/mobilenet-v2/
#
# 3. Blog 3 on MobileNet - https://medium.com/@yu4u/why-mobilenet-and-its-variants-e-g-shufflenet-are-fast-1c7048b9618d
#
# 4. Blog 1 on SSD - https://towardsdatascience.com/review-ssd-single-shot-detector-object-detection-851a94607d11
#
# 5. Blog 2 on SSD-512 - https://medium.com/@jonathan_hui/ssd-object-detection-single-shot-multibox-detector-for-real-time-processing-9bd8deac0e06
#
# 6. Blog 3 on SSD - https://towardsdatascience.com/understanding-ssd-multibox-real-time-object-detection-in-deep-learning-495ef744fab
#
# 7. Reference Tutorial - https://gluon.mxnet.io/chapter08_computer-vision/object-detection.html

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from detector_prototype import Detector

# %%
gtf = Detector();

# %% [markdown]
# # Sample Dataset Credits
#
# - credits: https://github.com/experiencor/kangaroo

# %%
root = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/";                         
img_dir = "Images/";                                                     
anno_file = "train_labels.csv";
batch_size=2;

# %%
gtf.Dataset(root, img_dir, anno_file, batch_size=batch_size);
# Out:
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))

# %%
pretrained = True;         
gpu=True;
model_name = "ssd_512_mobilenet1.0_voc";

# %%
gtf.Model(model_name, use_pretrained=pretrained, use_gpu=gpu);
# Out:
# /home/abhi/.virtualenvs/monk_obj_1_gluoncv_finetune/lib/python3.6/site-packages/mxnet/gluon/block.py:1159: UserWarning: Cannot decide type for the following arguments. Consider providing them as input:
# 	data: None
#   input_sym_arg_type = in_param.infer_type()[0]

# %%
gtf.Set_Learning_Rate(0.001);

# %%
epochs=10;
params_file = "saved_model.params";

# %%
gtf.Train(epochs, params_file);
# Out:
# [Epoch 0][Batch 0], Speed: 0.246 samples/sec, CrossEntropy=7.419, SmoothL1=2.083
# [Epoch 0][Batch 20], Speed: 7.409 samples/sec, CrossEntropy=4.404, SmoothL1=1.379
# [Epoch 0][Batch 40], Speed: 5.671 samples/sec, CrossEntropy=3.805, SmoothL1=1.349
# [Epoch 0][Batch 60], Speed: 9.413 samples/sec, CrossEntropy=3.424, SmoothL1=1.353
# [Epoch 0][Batch 80], Speed: 9.553 samples/sec, CrossEntropy=3.257, SmoothL1=1.363
# [Epoch 1][Batch 0], Speed: 7.938 samples/sec, CrossEntropy=2.191, SmoothL1=0.755
# [Epoch 1][Batch 20], Speed: 19.717 samples/sec, CrossEntropy=2.619, SmoothL1=1.330
# [Epoch 1][Batch 40], Speed: 16.002 samples/sec, CrossEntropy=2.546, SmoothL1=1.274
# [Epoch 1][Batch 60], Speed: 7.998 samples/sec, CrossEntropy=2.539, SmoothL1=1.355
# [Epoch 1][Batch 80], Speed: 9.156 samples/sec, CrossEntropy=2.546, SmoothL1=1.371
# [Epoch 2][Batch 0], Speed: 12.638 samples/sec, CrossEntropy=3.227, SmoothL1=1.450
# [Epoch 2][Batch 20], Speed: 9.358 samples/sec, CrossEntropy=2.462, SmoothL1=1.439
# [Epoch 2][Batch 40], Speed: 5.698 samples/sec, CrossEntropy=2.407, SmoothL1=1.348
# [Epoch 2][Batch 60], Speed: 10.386 samples/sec, CrossEntropy=2.364, SmoothL1=1.328
# [Epoch 2][Batch 80], Speed: 14.832 samples/sec, CrossEntropy=2.342, SmoothL1=1.264
# [Epoch 3][Batch 0], Speed: 14.267 samples/sec, CrossEntropy=2.323, SmoothL1=0.984
# [Epoch 3][Batch 20], Speed: 10.266 samples/sec, CrossEntropy=2.323, SmoothL1=1.143
# [Epoch 3][Batch 40], Speed: 12.249 samples/sec, CrossEntropy=2.284, SmoothL1=1.121
# [Epoch 3][Batch 60], Speed: 4.734 samples/sec, CrossEntropy=2.298, SmoothL1=1.097
# [Epoch 3][Batch 80], Speed: 9.798 samples/sec, CrossEntropy=2.302, SmoothL1=1.109
# [Epoch 4][Batch 0], Speed: 14.211 samples/sec, CrossEntropy=2.464, SmoothL1=1.315
# [Epoch 4][Batch 20], Speed: 15.595 samples/sec, CrossEntropy=2.261, SmoothL1=1.232
# [Epoch 4][Batch 40], Speed: 3.341 samples/sec, CrossEntropy=2.215, SmoothL1=1.146
# [Epoch 4][Batch 60], Speed: 17.614 samples/sec, CrossEntropy=2.224, SmoothL1=1.158
# [Epoch 4][Batch 80], Speed: 12.699 samples/sec, CrossEntropy=2.237, SmoothL1=1.175
# [Epoch 5][Batch 0], Speed: 7.285 samples/sec, CrossEntropy=2.002, SmoothL1=0.761
# [Epoch 5][Batch 20], Speed: 7.866 samples/sec, CrossEntropy=2.242, SmoothL1=1.101
# [Epoch 5][Batch 40], Speed: 15.524 samples/sec, CrossEntropy=2.241, SmoothL1=1.110
# [Epoch 5][Batch 60], Speed: 13.807 samples/sec, CrossEntropy=2.207, SmoothL1=1.115
# [Epoch 5][Batch 80], Speed: 13.171 samples/sec, CrossEntropy=2.208, SmoothL1=1.119
# [Epoch 6][Batch 0], Speed: 18.184 samples/sec, CrossEntropy=2.745, SmoothL1=1.488
# [Epoch 6][Batch 20], Speed: 17.777 samples/sec, CrossEntropy=2.202, SmoothL1=1.219
# [Epoch 6][Batch 40], Speed: 15.518 samples/sec, CrossEntropy=2.265, SmoothL1=1.097
# [Epoch 6][Batch 60], Speed: 16.551 samples/sec, CrossEntropy=2.219, SmoothL1=1.118
# [Epoch 6][Batch 80], Speed: 6.713 samples/sec, CrossEntropy=2.200, SmoothL1=1.094
# [Epoch 7][Batch 0], Speed: 16.262 samples/sec, CrossEntropy=2.429, SmoothL1=1.316
# [Epoch 7][Batch 20], Speed: 10.518 samples/sec, CrossEntropy=2.343, SmoothL1=1.075
# [Epoch 7][Batch 40], Speed: 20.608 samples/sec, CrossEntropy=2.308, SmoothL1=1.031
# [Epoch 7][Batch 60], Speed: 15.101 samples/sec, CrossEntropy=2.275, SmoothL1=1.042
# [Epoch 7][Batch 80], Speed: 15.659 samples/sec, CrossEntropy=2.200, SmoothL1=0.974
# [Epoch 8][Batch 0], Speed: 6.551 samples/sec, CrossEntropy=1.935, SmoothL1=2.211
# [Epoch 8][Batch 20], Speed: 8.005 samples/sec, CrossEntropy=2.217, SmoothL1=1.106
# [Epoch 8][Batch 40], Speed: 9.599 samples/sec, CrossEntropy=2.181, SmoothL1=1.041
# [Epoch 8][Batch 60], Speed: 17.582 samples/sec, CrossEntropy=2.176, SmoothL1=1.003
# [Epoch 8][Batch 80], Speed: 7.484 samples/sec, CrossEntropy=2.171, SmoothL1=1.037
# [Epoch 9][Batch 0], Speed: 15.979 samples/sec, CrossEntropy=1.694, SmoothL1=1.020
# [Epoch 9][Batch 20], Speed: 11.202 samples/sec, CrossEntropy=2.074, SmoothL1=0.924
# [Epoch 9][Batch 40], Speed: 7.754 samples/sec, CrossEntropy=2.103, SmoothL1=0.902
# [Epoch 9][Batch 60], Speed: 15.548 samples/sec, CrossEntropy=2.082, SmoothL1=0.880
# [Epoch 9][Batch 80], Speed: 16.676 samples/sec, CrossEntropy=2.103, SmoothL1=0.899

# %% [markdown]
# # Running Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from inference_prototype import Infer

# %%
model_name = "ssd_512_mobilenet1.0_voc";
params_file = "saved_model.params";
class_list = ["kangaroo"];

# %%
gtf = Infer(model_name, params_file, class_list, use_gpu=True);

# %%
img_name = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/test/kg1.jpeg"; 
visualize = True;
thresh = 0.9;

# %%
output = gtf.run(img_name, visualize=visualize, thresh=thresh);

# %% [markdown]
# # Author - Tessellate Imaging - https://www.tessellateimaging.com/
#
# # Monk Library - https://github.com/Tessellate-Imaging/monk_v1
#
#     Monk is an opensource low-code tool for computer vision and deep learning
#
#
# ## Monk features
#    - low-code
#    - unified wrapper over major deep learning framework - keras, pytorch, gluoncv
#    - syntax invariant wrapper
#
# ## Enables
#
#     - to create, manage and version control deep learning experiments
#     - to compare experiments across training metrics
#     - to quickly find best hyper-parameters
#
# ## At present it only supports transfer learning, but we are working each day to incorporate
#
#     - GUI based custom model creation
#     - various object detection and segmentation algorithms
#     - deployment pipelines to cloud and local platforms
#     - acceleration libraries such as TensorRT
#     - preprocessing and post processing libraries
#
#
# ## To contribute to Monk AI or Monk Object Detection repository raise an issue in the git-repo or dm us on linkedin
#
#     - Abhishek - https://www.linkedin.com/in/abhishek-kumar-annamraju/
#     - Akash - https://www.linkedin.com/in/akashdeepsingh01/
