# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/1_gluoncv_finetune/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install


# For Local systems and cloud select the right CUDA version
# !cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# ## Dataset Directory Structure
#
#     Parent_Directory (root)
#           |
#           |-----------Images (img_dir)
#           |              |
#           |              |------------------img1.jpg
#           |              |------------------img2.jpg
#           |              |------------------.........(and so on)
#           |
#           |
#           |-----------train_labels.csv (anno_file)
#
#
# ## Annotation file format
#
#            | Id         | Labels                                 |
#            | img1.jpg   | x1 y1 x2 y2 label1 x1 y1 x2 y2 label2  |
#
# - Labels:  xmin ymin xmax ymax label
# - xmin, ymin - top left corner of bounding box
# - xmax, ymax - bottom right corner of bounding box

# %% [markdown]
# # About the Network
#
# 1. Blog 1 on MobileNet - https://towardsdatascience.com/review-mobilenetv1-depthwise-separable-convolution-light-weight-model-a382df364b69
#
# 2. Blog 2 on MobileNet - https://machinethink.net/blog/mobilenet-v2/
#
# 3. Blog 3 on MobileNet - https://medium.com/@yu4u/why-mobilenet-and-its-variants-e-g-shufflenet-are-fast-1c7048b9618d
#
# 4. Blog 1 on SSD - https://towardsdatascience.com/review-ssd-single-shot-detector-object-detection-851a94607d11
#
# 5. Blog 2 on SSD-512 - https://medium.com/@jonathan_hui/ssd-object-detection-single-shot-multibox-detector-for-real-time-processing-9bd8deac0e06
#
# 6. Blog 3 on SSD - https://towardsdatascience.com/understanding-ssd-multibox-real-time-object-detection-in-deep-learning-495ef744fab
#
# 7. Reference Tutorial - https://gluon.mxnet.io/chapter08_computer-vision/object-detection.html

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from detector_prototype import Detector

# %%
gtf = Detector();

# %% [markdown]
# # Sample Dataset Credits
#
# - credits: https://github.com/experiencor/kangaroo

# %%
root = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/";                         
img_dir = "Images/";                                                     
anno_file = "train_labels.csv";
batch_size=2;

# %%
gtf.Dataset(root, img_dir, anno_file, batch_size=batch_size);
# Out:
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))

# %%
pretrained = True;         
gpu=True;
model_name = "ssd_512_mobilenet1.0_coco";

# %%
gtf.Model(model_name, use_pretrained=pretrained, use_gpu=gpu);
# Out:
# /home/abhi/.virtualenvs/monk_obj_1_gluoncv_finetune/lib/python3.6/site-packages/mxnet/gluon/block.py:1159: UserWarning: Cannot decide type for the following arguments. Consider providing them as input:
# 	data: None
#   input_sym_arg_type = in_param.infer_type()[0]

# %%
gtf.Set_Learning_Rate(0.001);

# %%
epochs=10;
params_file = "saved_model.params";

# %%
gtf.Train(epochs, params_file);
# Out:
# [Epoch 0][Batch 0], Speed: 0.198 samples/sec, CrossEntropy=8.327, SmoothL1=0.885
# [Epoch 0][Batch 20], Speed: 17.184 samples/sec, CrossEntropy=4.546, SmoothL1=1.158
# [Epoch 0][Batch 40], Speed: 9.301 samples/sec, CrossEntropy=3.933, SmoothL1=1.388
# [Epoch 0][Batch 60], Speed: 6.747 samples/sec, CrossEntropy=3.585, SmoothL1=1.407
# [Epoch 0][Batch 80], Speed: 16.567 samples/sec, CrossEntropy=3.392, SmoothL1=1.482
# [Epoch 1][Batch 0], Speed: 13.181 samples/sec, CrossEntropy=2.831, SmoothL1=1.605
# [Epoch 1][Batch 20], Speed: 11.325 samples/sec, CrossEntropy=2.954, SmoothL1=1.475
# [Epoch 1][Batch 40], Speed: 10.647 samples/sec, CrossEntropy=2.840, SmoothL1=1.450
# [Epoch 1][Batch 60], Speed: 9.023 samples/sec, CrossEntropy=2.766, SmoothL1=1.414
# [Epoch 1][Batch 80], Speed: 19.099 samples/sec, CrossEntropy=2.732, SmoothL1=1.385
# [Epoch 2][Batch 0], Speed: 17.268 samples/sec, CrossEntropy=3.788, SmoothL1=1.801
# [Epoch 2][Batch 20], Speed: 9.542 samples/sec, CrossEntropy=2.688, SmoothL1=1.465
# [Epoch 2][Batch 40], Speed: 4.736 samples/sec, CrossEntropy=2.683, SmoothL1=1.471
# [Epoch 2][Batch 60], Speed: 11.870 samples/sec, CrossEntropy=2.551, SmoothL1=1.413
# [Epoch 2][Batch 80], Speed: 10.826 samples/sec, CrossEntropy=2.549, SmoothL1=1.384
# [Epoch 3][Batch 0], Speed: 8.714 samples/sec, CrossEntropy=2.453, SmoothL1=1.302
# [Epoch 3][Batch 20], Speed: 16.677 samples/sec, CrossEntropy=2.387, SmoothL1=1.350
# [Epoch 3][Batch 40], Speed: 17.158 samples/sec, CrossEntropy=2.481, SmoothL1=1.375
# [Epoch 3][Batch 60], Speed: 14.283 samples/sec, CrossEntropy=2.457, SmoothL1=1.349
# [Epoch 3][Batch 80], Speed: 15.605 samples/sec, CrossEntropy=2.474, SmoothL1=1.330
# [Epoch 4][Batch 0], Speed: 14.384 samples/sec, CrossEntropy=2.313, SmoothL1=1.182
# [Epoch 4][Batch 20], Speed: 16.153 samples/sec, CrossEntropy=2.333, SmoothL1=1.207
# [Epoch 4][Batch 40], Speed: 11.285 samples/sec, CrossEntropy=2.237, SmoothL1=1.224
# [Epoch 4][Batch 60], Speed: 12.801 samples/sec, CrossEntropy=2.256, SmoothL1=1.218
# [Epoch 4][Batch 80], Speed: 5.415 samples/sec, CrossEntropy=2.272, SmoothL1=1.213
# [Epoch 5][Batch 0], Speed: 12.842 samples/sec, CrossEntropy=2.479, SmoothL1=2.196
# [Epoch 5][Batch 20], Speed: 20.183 samples/sec, CrossEntropy=2.345, SmoothL1=1.136
# [Epoch 5][Batch 40], Speed: 14.799 samples/sec, CrossEntropy=2.371, SmoothL1=1.192
# [Epoch 5][Batch 60], Speed: 12.671 samples/sec, CrossEntropy=2.331, SmoothL1=1.193
# [Epoch 5][Batch 80], Speed: 17.102 samples/sec, CrossEntropy=2.299, SmoothL1=1.183
# [Epoch 6][Batch 0], Speed: 3.930 samples/sec, CrossEntropy=1.765, SmoothL1=0.682
# [Epoch 6][Batch 20], Speed: 18.270 samples/sec, CrossEntropy=2.289, SmoothL1=1.152
# [Epoch 6][Batch 40], Speed: 12.280 samples/sec, CrossEntropy=2.305, SmoothL1=1.178
# [Epoch 6][Batch 60], Speed: 11.088 samples/sec, CrossEntropy=2.347, SmoothL1=1.222
# [Epoch 6][Batch 80], Speed: 15.590 samples/sec, CrossEntropy=2.361, SmoothL1=1.223
# [Epoch 7][Batch 0], Speed: 13.747 samples/sec, CrossEntropy=2.243, SmoothL1=1.381
# [Epoch 7][Batch 20], Speed: 16.649 samples/sec, CrossEntropy=2.232, SmoothL1=1.197
# [Epoch 7][Batch 40], Speed: 13.386 samples/sec, CrossEntropy=2.282, SmoothL1=1.183
# [Epoch 7][Batch 60], Speed: 16.488 samples/sec, CrossEntropy=2.276, SmoothL1=1.169
# [Epoch 7][Batch 80], Speed: 8.990 samples/sec, CrossEntropy=2.281, SmoothL1=1.188
# [Epoch 8][Batch 0], Speed: 13.610 samples/sec, CrossEntropy=1.879, SmoothL1=0.525
# [Epoch 8][Batch 20], Speed: 8.917 samples/sec, CrossEntropy=2.284, SmoothL1=1.068
# [Epoch 8][Batch 40], Speed: 17.470 samples/sec, CrossEntropy=2.156, SmoothL1=0.975
# [Epoch 8][Batch 60], Speed: 16.401 samples/sec, CrossEntropy=2.148, SmoothL1=1.034
# [Epoch 8][Batch 80], Speed: 10.957 samples/sec, CrossEntropy=2.139, SmoothL1=1.039
# [Epoch 9][Batch 0], Speed: 6.984 samples/sec, CrossEntropy=1.956, SmoothL1=1.422
# [Epoch 9][Batch 20], Speed: 12.479 samples/sec, CrossEntropy=2.275, SmoothL1=0.995
# [Epoch 9][Batch 40], Speed: 9.097 samples/sec, CrossEntropy=2.208, SmoothL1=0.960
# [Epoch 9][Batch 60], Speed: 13.597 samples/sec, CrossEntropy=2.200, SmoothL1=0.982
# [Epoch 9][Batch 80], Speed: 9.469 samples/sec, CrossEntropy=2.187, SmoothL1=1.003

# %% [markdown]
# # Running Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from inference_prototype import Infer

# %%
model_name = "ssd_512_mobilenet1.0_coco";
params_file = "saved_model.params";
class_list = ["kangaroo"];

# %%
gtf = Infer(model_name, params_file, class_list, use_gpu=True);

# %%
img_name = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/test/kg2.jpeg"; 
visualize = True;
thresh = 0.5;

# %%
output = gtf.run(img_name, visualize=visualize, thresh=thresh);

# %% [markdown]
# # Author - Tessellate Imaging - https://www.tessellateimaging.com/
#
# # Monk Library - https://github.com/Tessellate-Imaging/monk_v1
#
#     Monk is an opensource low-code tool for computer vision and deep learning
#
#
# ## Monk features
#    - low-code
#    - unified wrapper over major deep learning framework - keras, pytorch, gluoncv
#    - syntax invariant wrapper
#
# ## Enables
#
#     - to create, manage and version control deep learning experiments
#     - to compare experiments across training metrics
#     - to quickly find best hyper-parameters
#
# ## At present it only supports transfer learning, but we are working each day to incorporate
#
#     - GUI based custom model creation
#     - various object detection and segmentation algorithms
#     - deployment pipelines to cloud and local platforms
#     - acceleration libraries such as TensorRT
#     - preprocessing and post processing libraries
#
#
# ## To contribute to Monk AI or Monk Object Detection repository raise an issue in the git-repo or dm us on linkedin
#
#     - Abhishek - https://www.linkedin.com/in/abhishek-kumar-annamraju/
#     - Akash - https://www.linkedin.com/in/akashdeepsingh01/
