# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/1_gluoncv_finetune/TRAIN-gluon-ssd_512_vgg16_atrous_coco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/1_gluoncv_finetune/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install


# For Local systems and cloud select the right CUDA version
# !cd Monk_Object_Detection/1_gluoncv_finetune/installation && cat requirements_cuda9.0.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# ## Dataset Directory Structure
#
#     Parent_Directory (root)
#           |
#           |-----------Images (img_dir)
#           |              |
#           |              |------------------img1.jpg
#           |              |------------------img2.jpg
#           |              |------------------.........(and so on)
#           |
#           |
#           |-----------train_labels.csv (anno_file)
#
#
# ## Annotation file format
#
#            | Id         | Labels                                 |
#            | img1.jpg   | x1 y1 x2 y2 label1 x1 y1 x2 y2 label2  |
#
# - Labels:  xmin ymin xmax ymax label
# - xmin, ymin - top left corner of bounding box
# - xmax, ymax - bottom right corner of bounding box

# %% [markdown]
# # About the Network
#
# 1. Blog 1 on VGG Network - https://towardsdatascience.com/vgg-neural-networks-the-next-step-after-alexnet-3f91fa9ffe2c
#
# 2. Blog 2 on VGG Network - https://medium.com/coinmonks/paper-review-of-vggnet-1st-runner-up-of-ilsvlc-2014-image-classification-d02355543a11
#
# 3. Blog 1 on SSD - https://towardsdatascience.com/review-ssd-single-shot-detector-object-detection-851a94607d11
#
# 4. Blog 2 on SSD-512 - https://medium.com/@jonathan_hui/ssd-object-detection-single-shot-multibox-detector-for-real-time-processing-9bd8deac0e06
#
# 5. Blog 3 on SSD - https://towardsdatascience.com/understanding-ssd-multibox-real-time-object-detection-in-deep-learning-495ef744fab
#
# 6. Blog on Atrous Convolution - https://towardsdatascience.com/review-deeplabv1-deeplabv2-atrous-convolution-semantic-segmentation-b51c5fbde92d
#
# 7. Reference Tutorial - https://gluon.mxnet.io/chapter08_computer-vision/object-detection.html

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from detector_prototype import Detector

# %%
gtf = Detector();

# %% [markdown]
# # Sample Dataset Credits
#
# - credits: https://github.com/experiencor/kangaroo

# %%
root = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/";                         
img_dir = "Images/";                                                     
anno_file = "train_labels.csv";
batch_size=2;

# %%
gtf.Dataset(root, img_dir, anno_file, batch_size=batch_size);
# Out:
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=164.0), HTML(value='')))

# %%
pretrained = True;         
gpu=True;
model_name = "ssd_512_vgg16_atrous_coco";

# %%
gtf.Model(model_name, use_pretrained=pretrained, use_gpu=gpu);

# %%
gtf.Set_Learning_Rate(0.001);

# %%
epochs=10;
params_file = "saved_model.params";

# %%
gtf.Train(epochs, params_file);
# Out:
# [Epoch 0][Batch 0], Speed: 0.335 samples/sec, CrossEntropy=15.844, SmoothL1=0.340
# [Epoch 0][Batch 20], Speed: 7.161 samples/sec, CrossEntropy=4.750, SmoothL1=1.859
# [Epoch 0][Batch 40], Speed: 3.382 samples/sec, CrossEntropy=3.908, SmoothL1=1.922
# [Epoch 0][Batch 60], Speed: 5.554 samples/sec, CrossEntropy=3.524, SmoothL1=1.844
# [Epoch 0][Batch 80], Speed: 6.211 samples/sec, CrossEntropy=3.295, SmoothL1=1.696
# [Epoch 1][Batch 0], Speed: 7.961 samples/sec, CrossEntropy=2.612, SmoothL1=1.409
# [Epoch 1][Batch 20], Speed: 3.721 samples/sec, CrossEntropy=2.611, SmoothL1=1.461
# [Epoch 1][Batch 40], Speed: 8.008 samples/sec, CrossEntropy=2.585, SmoothL1=1.280
# [Epoch 1][Batch 60], Speed: 7.473 samples/sec, CrossEntropy=2.523, SmoothL1=1.247
# [Epoch 1][Batch 80], Speed: 8.592 samples/sec, CrossEntropy=2.472, SmoothL1=1.207
# [Epoch 2][Batch 0], Speed: 6.698 samples/sec, CrossEntropy=2.514, SmoothL1=0.908
# [Epoch 2][Batch 20], Speed: 8.119 samples/sec, CrossEntropy=2.357, SmoothL1=1.205
# [Epoch 2][Batch 40], Speed: 4.336 samples/sec, CrossEntropy=2.367, SmoothL1=1.197
# [Epoch 2][Batch 60], Speed: 7.133 samples/sec, CrossEntropy=2.336, SmoothL1=1.138
# [Epoch 2][Batch 80], Speed: 6.071 samples/sec, CrossEntropy=2.324, SmoothL1=1.107
# [Epoch 3][Batch 0], Speed: 6.844 samples/sec, CrossEntropy=2.276, SmoothL1=1.091
# [Epoch 3][Batch 20], Speed: 7.528 samples/sec, CrossEntropy=2.325, SmoothL1=1.204
# [Epoch 3][Batch 40], Speed: 5.627 samples/sec, CrossEntropy=2.319, SmoothL1=1.160
# [Epoch 3][Batch 60], Speed: 8.432 samples/sec, CrossEntropy=2.320, SmoothL1=1.118
# [Epoch 3][Batch 80], Speed: 7.106 samples/sec, CrossEntropy=2.307, SmoothL1=1.131
# [Epoch 4][Batch 0], Speed: 6.848 samples/sec, CrossEntropy=2.692, SmoothL1=2.137
# [Epoch 4][Batch 20], Speed: 4.303 samples/sec, CrossEntropy=2.264, SmoothL1=1.095
# [Epoch 4][Batch 40], Speed: 9.022 samples/sec, CrossEntropy=2.229, SmoothL1=1.002
# [Epoch 4][Batch 60], Speed: 5.831 samples/sec, CrossEntropy=2.219, SmoothL1=1.076
# [Epoch 4][Batch 80], Speed: 6.139 samples/sec, CrossEntropy=2.217, SmoothL1=1.034
# [Epoch 5][Batch 0], Speed: 7.907 samples/sec, CrossEntropy=1.894, SmoothL1=1.128
# [Epoch 5][Batch 20], Speed: 5.266 samples/sec, CrossEntropy=2.275, SmoothL1=0.965
# [Epoch 5][Batch 40], Speed: 9.166 samples/sec, CrossEntropy=2.254, SmoothL1=1.073
# [Epoch 5][Batch 60], Speed: 6.316 samples/sec, CrossEntropy=2.211, SmoothL1=1.040
# [Epoch 5][Batch 80], Speed: 5.238 samples/sec, CrossEntropy=2.165, SmoothL1=1.009
# [Epoch 6][Batch 0], Speed: 7.632 samples/sec, CrossEntropy=1.657, SmoothL1=0.602
# [Epoch 6][Batch 20], Speed: 8.379 samples/sec, CrossEntropy=1.960, SmoothL1=0.871
# [Epoch 6][Batch 40], Speed: 3.059 samples/sec, CrossEntropy=2.033, SmoothL1=0.857
# [Epoch 6][Batch 60], Speed: 6.983 samples/sec, CrossEntropy=2.051, SmoothL1=0.877
# [Epoch 6][Batch 80], Speed: 6.446 samples/sec, CrossEntropy=2.043, SmoothL1=0.901
# [Epoch 7][Batch 0], Speed: 7.439 samples/sec, CrossEntropy=1.953, SmoothL1=1.307
# [Epoch 7][Batch 20], Speed: 7.525 samples/sec, CrossEntropy=1.826, SmoothL1=0.708
# [Epoch 7][Batch 40], Speed: 5.863 samples/sec, CrossEntropy=1.876, SmoothL1=0.800
# [Epoch 7][Batch 60], Speed: 6.495 samples/sec, CrossEntropy=1.877, SmoothL1=0.759
# [Epoch 7][Batch 80], Speed: 5.296 samples/sec, CrossEntropy=1.880, SmoothL1=0.740
# [Epoch 8][Batch 0], Speed: 7.942 samples/sec, CrossEntropy=1.953, SmoothL1=1.252
# [Epoch 8][Batch 20], Speed: 5.586 samples/sec, CrossEntropy=1.955, SmoothL1=0.855
# [Epoch 8][Batch 40], Speed: 8.213 samples/sec, CrossEntropy=1.903, SmoothL1=0.809
# [Epoch 8][Batch 60], Speed: 7.427 samples/sec, CrossEntropy=1.930, SmoothL1=0.768
# [Epoch 8][Batch 80], Speed: 8.059 samples/sec, CrossEntropy=1.904, SmoothL1=0.744
# [Epoch 9][Batch 0], Speed: 4.909 samples/sec, CrossEntropy=2.369, SmoothL1=1.333
# [Epoch 9][Batch 20], Speed: 9.244 samples/sec, CrossEntropy=1.858, SmoothL1=0.808
# [Epoch 9][Batch 40], Speed: 6.005 samples/sec, CrossEntropy=1.980, SmoothL1=0.879
# [Epoch 9][Batch 60], Speed: 7.544 samples/sec, CrossEntropy=1.933, SmoothL1=0.853
# [Epoch 9][Batch 80], Speed: 3.066 samples/sec, CrossEntropy=1.919, SmoothL1=0.855

# %% [markdown]
# # Running Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/1_gluoncv_finetune/lib/");

# %%
from inference_prototype import Infer

# %%
model_name = "ssd_512_vgg16_atrous_coco";
params_file = "saved_model.params";
class_list = ["kangaroo"];

# %%
gtf = Infer(model_name, params_file, class_list, use_gpu=True);

# %%
img_name = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/test/kg1.jpeg"; 
visualize = True;
thresh = 0.8;

# %%
output = gtf.run(img_name, visualize=visualize, thresh=thresh);

# %% [markdown]
# # Author - Tessellate Imaging - https://www.tessellateimaging.com/
#
# # Monk Library - https://github.com/Tessellate-Imaging/monk_v1
#
#     Monk is an opensource low-code tool for computer vision and deep learning
#
#
# ## Monk features
#    - low-code
#    - unified wrapper over major deep learning framework - keras, pytorch, gluoncv
#    - syntax invariant wrapper
#
# ## Enables
#
#     - to create, manage and version control deep learning experiments
#     - to compare experiments across training metrics
#     - to quickly find best hyper-parameters
#
# ## At present it only supports transfer learning, but we are working each day to incorporate
#
#     - GUI based custom model creation
#     - various object detection and segmentation algorithms
#     - deployment pipelines to cloud and local platforms
#     - acceleration libraries such as TensorRT
#     - preprocessing and post processing libraries
#
#
# ## To contribute to Monk AI or Monk Object Detection repository raise an issue in the git-repo or dm us on linkedin
#
#     - Abhishek - https://www.linkedin.com/in/abhishek-kumar-annamraju/
#     - Akash - https://www.linkedin.com/in/akashdeepsingh01/
