# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/inference_engine/Object%20Detection%20-%20EfficientDet%20Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/inference_engine/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements.txt | xargs -n 1 -L 1 pip install

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/inference_engine/installation && cat requirements_colab.txt | xargs -n 1 -L 1 pip install

# For Local systems and cloud select the right CUDA version
#! cd Monk_Object_Detection/inference_engine/installation && cat requirements_cuda.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# # Imports

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/inference_engine/")

# %%
from engine import Infer
gtf = Infer();

# %% [markdown]
# # List available algorithms

# %%
gtf.List_Algo_Types();
# Out:
# Available Algorithm Types:
# 1. object_detection
# 2. image_segmentation
# 3. pose_estimation
# 4. face_recognition
# 5. facial_keypoint_detection
# 6. activity_classification
# 7. gaze_estimation
# 8. object_tracking

# %% [markdown]
# # List available algorithm types in Object Detection

# %%
gtf.List_Algos(algo_type="object_detection");
# Out:
# Available Object Detection Algorithms:
# 1. gluoncv_finetune
# 2. efficientdet_pytorch

# %% [markdown]
# # Install EfficientDet Pytorch Algorithm

# %%
gtf.Install_Engine(algo_type="object_detection", algo="efficientdet_pytorch", system="cuda-9.0")

# %% [markdown]
# # List all models present in EfficientDet Pytorch Algorithm

# %%
gtf.List_Model_Names(algo_type="object_detection", algo="efficientdet_pytorch");
# Out:
# Available models:
# 1. Data: coco, Model-Name: efficientdet-d0, mAP: 33.1
# 2. Data: coco, Model-Name: efficientdet-d1, mAP: 38.8
# 3. Data: coco, Model-Name: efficientdet-d2, mAP: 42.1
# 4. Data: coco, Model-Name: efficientdet-d3, mAP: 45.6
# 5. Data: coco, Model-Name: efficientdet-d4, mAP: 48.8
# 6. Data: coco, Model-Name: efficientdet-d5, mAP: 50.2
# 7. Data: coco, Model-Name: efficientdet-d6, mAP: 50.7
# 8. Data: coco, Model-Name: efficientdet-d7, mAP: 51.2

# %% [markdown]
# # List all elements in coco dataset

# %%
gtf.List_Classes(data="coco");
# Out:
# 1. Class: airplane
# 2. Class: apple
# 3. Class: backpack
# 4. Class: banana
# 5. Class: baseball bat
# 6. Class: baseball glove
# 7. Class: bear
# 8. Class: bed
# 9. Class: bench
# 10. Class: bicycle
# 11. Class: bird
# 12. Class: boat
# 13. Class: book
# 14. Class: bottle
# 15. Class: bowl
# 16. Class: broccoli
# 17. Class: bus
# 18. Class: cake
# 19. Class: car
# 20. Class: carrot
# 21. Class: cat
# 22. Class: cell phone
# 23. Class: chair
# 24. Class: clock
# 25. Class: couch
# 26. Class: cow
# 27. Class: cup
# 28. Class: dining table
# 29. Class: dog
# 30. Class: donut
# 31. Class: elephant
# 32. Class: fire hydrant
# 33. Class: fork
# 34. Class: frisbee
# 35. Class: giraffe
# 36. Class: hair drier
# 37. Class: handbag
# 38. Class: horse
# 39. Class: hot dog
# 40. Class: keyboard
# 41. Class: kite
# 42. Class: knife
# 43. Class: laptop
# 44. Class: microwave
# 45. Class: motorcycle
# 46. Class: mouse
# 47. Class: orange
# 48. Class: oven
# 49. Class: parking meter
# 50. Class: person
# 51. Class: pizza
# 52. Class: potted plant
# 53. Class: refrigerator
# 54. Class: remote
# 55. Class: sandwich
# 56. Class: scissors
# 57. Class: sheep
# 58. Class: sink
# 59. Class: skateboard
# 60. Class: skis
# 61. Class: snowboard
# 62. Class: spoon
# 63. Class: sports ball
# 64. Class: stop sign
# 65. Class: suitcase
# 66. Class: surfboard
# 67. Class: teddy bear
# 68. Class: tennis racket
# 69. Class: tie
# 70. Class: toaster
# 71. Class: toilet
# 72. Class: toothbrush
# 73. Class: traffic light
# 74. Class: train
# 75. Class: truck
# 76. Class: tv
# 77. Class: umbrella
# 78. Class: vase
# 79. Class: wine glass
# 80. Class: zebra

# %% [markdown]
# # Infer on a single Image

# %%
classes1 = "car, person"; # For a set of classes
classes2 = "person"; # For one single class
classes3 = ""; # For all classes

gtf.Infer_Image(algo_type="object_detection", 
                algo="efficientdet_pytorch",
                data="coco",
                model="efficientdet-d1",
                img_path="test.png",
                thresh=0.3,
                classes = classes1,
                visualize=True,
                write_voc_format=True,
                write_coco_format=True,
                write_monk_format=True,
                write_yolo_format=True,
                verbose=1);
# Out:
# Running Inference
# If running for the first time, it might take a little longer ....
# Downloading model ....
# Loading Model ...
# Running Inference on Image ...
# Saving Annotations to monk format
# Saving Annotations to coco format (individual files)
# Saving Annotations to voc format
# Saving Annotations to yolo format
# Completed
# Output stored at workspace/object_detection/efficientdet_pytorch/efficientdet-d1/test.jpg

# %% [markdown]
# # Infer on a Folder of Images

# %%
classes1 = "car, person"; # For a set of classes
classes2 = "person"; # For one single class
classes3 = ""; # For all classes

gtf.Infer_Folder_Images(algo_type="object_detection", 
                        algo="efficientdet_pytorch",
                        data="coco",
                        model="efficientdet-d1",
                        folder_path="test_folder",
                        output_folder_name="test_folder",
                        thresh=0.5,
                        classes = classes1,
                        visualize=False,
                        write_voc_format=True,
                        write_coco_format=True,
                        write_monk_format=True,
                        write_yolo_format=True,
                        verbose=1);
# Out:
# Running Inference
# If running for the first time, it might take a little longer ....
# Downloading model ....
# Loading Model ...
# Already Processed 1/6
# Already Processed 2/6
# Already Processed 3/6
# Already Processed 4/6
# Processing 5/6
# Saving Annotations to monk format
# Saving Annotations to coco format (individual files)
# Saving Annotations to voc format
# Saving Annotations to yolo format
# Processing 6/6
# Saving Annotations to monk format
# Saving Annotations to coco format (individual files)
# Saving Annotations to voc format
# Saving Annotations to yolo format
# Completed
#
#
# Output stored at workspace/object_detection/efficientdet_pytorch/efficientdet-d1/test_folder/
