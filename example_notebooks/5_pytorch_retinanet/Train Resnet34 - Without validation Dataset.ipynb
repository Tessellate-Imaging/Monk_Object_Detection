# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/5_pytorch_retinanet/installation
#
#  - Select the right requirements file and run
#
#      - cat requirements.txt | xargs -n 1 -L 1 pip install

# %% [markdown]
# # About the network
#
# 1. Paper on Focal Loss: https://arxiv.org/abs/1708.02002
#
# 2. Blog 1 on RetinaNet: https://medium.com/@14prakash/the-intuition-behind-retinanet-eb636755607d
#
# 3. Blog 2 on RetinaNet: https://blog.zenggyu.com/en/post/2018-12-05/retinanet-explained-and-demystified/
#
# 4. Blog 3 on RetinaNet: https://towardsdatascience.com/review-retinanet-focal-loss-object-detection-38fba6afabe4
#
# 5. Blog 4 on RetinaNet: https://analyticsindiamag.com/what-is-retinanet-ssd-focal-loss/
#
# 6. Blog 5 on RetinaNet: https://towardsdatascience.com/object-detection-on-aerial-imagery-using-retinanet-626130ba2203

# %% [markdown]
# # COCO Format - 1
#
# ## Dataset Directory Structure
#
#     ../sample_dataset (root_dir)
#           |
#           |------ship (coco_dir)
#           |         |
#           |         |----images (img_dir)
#           |                |
#           |                |------Train (set_dir) (Train)
#           |                         |
#           |                         |---------img1.jpg
#           |                         |---------img2.jpg
#           |                         |---------..........(and so on)
#           |
#           |
#           |         |---annotations
#           |         |----|
#           |              |--------------------instances_Train.json  (instances_<set_dir>.json)
#           |              |--------------------classes.txt
#
#
#  - instances_Train.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order
#
#
# For TrainSet
#  - root_dir = "../sample_dataset";
#  - coco_dir = "ship";
#  - img_dir = "images";
#  - set_dir = "Train";
#
#
#  Note: Annotation file name too coincides against the set_dir

# %% [markdown]
# # COCO Format - 2
#
# ## Dataset Directory Structure
#
#     ../sample_dataset (root_dir)
#           |
#           |------ship (coco_dir)
#           |         |
#           |         |---ImagesTrain (set_dir)
#           |         |----|
#           |              |-------------------img1.jpg
#           |              |-------------------img2.jpg
#           |              |-------------------.........(and so on)
#           |
#           |
#           |         |---annotations
#           |         |----|
#           |              |--------------------instances_ImagesTrain.json  (instances_<set_dir>.json)
#           |              |--------------------classes.txt
#
#
#  - instances_Train.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order
#
#  For TrainSet
#  - root_dir = "../sample_dataset";
#  - coco_dir = "ship";
#  - img_dir = "./";
#  - set_dir = "ImagesTrain";
#
#
#  Note: Annotation file name too coincides against the set_dir

# %% [markdown]
# # Sample Dataset Credits
#
#     credits: https://www.tejashwi.io/object-detection-with-fizyr-retinanet/

# %%
import os
import sys
sys.path.append("../../5_pytorch_retinanet/lib/");

# %%
from train_detector import Detector

# %%
gtf = Detector();

# %%
root_dir = "../sample_dataset";
coco_dir = "ship";
img_dir = "./";
set_dir = "Images";

# %%
gtf.Train_Dataset(root_dir, coco_dir, img_dir, set_dir, batch_size=4, use_gpu=True)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Num training images: 750

# %% [markdown]
# ## Models available
#   - resnet18
#   - resnet34
#   - resnet50
#   - resnet101
#   - resnet152

# %%
gtf.Model(model_name="resnet34");
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to ./resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:04<00:00, 17.8MB/s]

# %%
gtf.Set_Hyperparams(lr=0.0001, val_interval=1, print_interval=20)

# %%
gtf.Train(num_epochs=5, output_model_name="final_model.pt");
# Out:
# Epoch: 0 | Iteration: 0 | Classification loss: 1.13468 | Regression loss: 1.04460 | Running loss: 2.17927
# Epoch: 0 | Iteration: 20 | Classification loss: 0.50653 | Regression loss: 0.69821 | Running loss: 2.53134
# Epoch: 0 | Iteration: 40 | Classification loss: 0.41545 | Regression loss: 0.68183 | Running loss: 1.73193
# Epoch: 0 | Iteration: 60 | Classification loss: 0.26835 | Regression loss: 0.66855 | Running loss: 1.41599
# Epoch: 0 | Iteration: 80 | Classification loss: 0.22718 | Regression loss: 0.45793 | Running loss: 1.24887
# Epoch: 0 | Iteration: 100 | Classification loss: 0.19725 | Regression loss: 0.57775 | Running loss: 1.13883
# Epoch: 0 | Iteration: 120 | Classification loss: 0.24923 | Regression loss: 0.47424 | Running loss: 1.06759
# Epoch: 0 | Iteration: 140 | Classification loss: 0.15139 | Regression loss: 0.36934 | Running loss: 1.01584
# Epoch: 0 | Iteration: 160 | Classification loss: 0.18615 | Regression loss: 0.47455 | Running loss: 0.96738
# Epoch: 0 | Iteration: 180 | Classification loss: 0.27072 | Regression loss: 0.46734 | Running loss: 0.93091
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type DataParallel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ResNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BasicBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type PyramidFeatures. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Upsample. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type RegressionModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ClassificationModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sigmoid. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/abhi/.virtualenvs/monk_obj_5_retinanet/lib/python3.6/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Anchors. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
#
# Epoch: 3 | Iteration: 80 | Classification loss: 0.09516 | Regression loss: 0.30192 | Running loss: 0.49454
# Epoch: 3 | Iteration: 100 | Classification loss: 0.08155 | Regression loss: 0.28882 | Running loss: 0.48650
# Epoch: 3 | Iteration: 120 | Classification loss: 0.03212 | Regression loss: 0.21054 | Running loss: 0.47667
# Epoch: 3 | Iteration: 140 | Classification loss: 0.24667 | Regression loss: 0.32663 | Running loss: 0.46855
# Epoch: 3 | Iteration: 160 | Classification loss: 0.21825 | Regression loss: 0.41423 | Running loss: 0.46179
# Epoch: 3 | Iteration: 180 | Classification loss: 0.04299 | Regression loss: 0.22842 | Running loss: 0.45461
# Epoch: 4 | Iteration: 0 | Classification loss: 0.08240 | Regression loss: 0.27358 | Running loss: 0.45196
# Epoch: 4 | Iteration: 20 | Classification loss: 0.01372 | Regression loss: 0.12410 | Running loss: 0.44686
# Epoch: 4 | Iteration: 40 | Classification loss: 0.13446 | Regression loss: 0.32923 | Running loss: 0.43856
# Epoch: 4 | Iteration: 60 | Classification loss: 0.10052 | Regression loss: 0.38490 | Running loss: 0.43386
# Epoch: 4 | Iteration: 80 | Classification loss: 0.05034 | Regression loss: 0.22361 | Running loss: 0.42865
# Epoch: 4 | Iteration: 100 | Classification loss: 0.18364 | Regression loss: 0.39072 | Running loss: 0.42607
# Epoch: 4 | Iteration: 120 | Classification loss: 0.06364 | Regression loss: 0.25825 | Running loss: 0.42192
# Epoch: 4 | Iteration: 140 | Classification loss: 0.09074 | Regression loss: 0.24524 | Running loss: 0.41621
# Epoch: 4 | Iteration: 160 | Classification loss: 0.05682 | Regression loss: 0.23597 | Running loss: 0.41430
# Epoch: 4 | Iteration: 180 | Classification loss: 0.11762 | Regression loss: 0.31000 | Running loss: 0.41245

# %% [markdown]
# # Inference

# %%
import os
import sys
sys.path.append("../../5_pytorch_retinanet/lib/");

# %%
from infer_detector import Infer

# %%
gtf = Infer();

# %%
gtf.Model(model_path="final_model.pt");

# %%
f = open("../sample_dataset/ship/annotations/classes.txt", 'r');
class_list = f.readlines();
f.close();
for i in range(len(class_list)):
    class_list[i] = class_list[i][:-1]

# %%
class_list
# Out:
# ['type-0', 'type-1', 'type-2', 'type-3', 'type-4']

# %%
img_path = "../sample_dataset/ship/test/img1.jpg";
scores, labels, boxes = gtf.Predict(img_path, class_list, vis_threshold=0.4);
from IPython.display import Image
Image(filename='output.jpg')

# %%
img_path = "../sample_dataset/ship/test/img4.jpg";
scores, labels, boxes = gtf.Predict(img_path, class_list, vis_threshold=0.4);
from IPython.display import Image
Image(filename='output.jpg')

# %%
img_path = "../sample_dataset/ship/test/img5.jpg";
scores, labels, boxes = gtf.Predict(img_path, class_list, vis_threshold=0.4);
from IPython.display import Image
Image(filename='output.jpg')

# %%
img_path = "../sample_dataset/ship/test/img6.jpg";
scores, labels, boxes = gtf.Predict(img_path, class_list, vis_threshold=0.4);
from IPython.display import Image
Image(filename='output.jpg')
