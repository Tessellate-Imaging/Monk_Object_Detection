# %% [markdown]
# <a href="https://colab.research.google.com/github/Tessellate-Imaging/Monk_Object_Detection/blob/master/example_notebooks/8_pytorch_rfbnet/Train%20and%20Infer%20-%20VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation
#
#  - Run these commands
#
#      - git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git
#
#      - cd Monk_Object_Detection/8_pytorch_rfbnet/installation
#
#  - Select the right requirements file and run
#
#      - chmod +x install.sh
#
#      - ./install.sh

# %%
! git clone https://github.com/Tessellate-Imaging/Monk_Object_Detection.git

# %%
# For colab use the command below
! cd Monk_Object_Detection/8_pytorch_rfbnet/installation && chmod +x install_colab.sh && ./install_colab.sh
# Restart colab runtime now

# For Local systems and cloud select the right CUDA version
# ! cd Monk_Object_Detection/8_pytorch_rfbnet/installation && chmod +x install.sh && ./install.sh

# %% [markdown]
# # About the network
#
# 1. Paper on RBFNet: https://arxiv.org/abs/1711.07767
#
# 2. Blog 1 on Receptive field: http://blog.christianperone.com/2017/11/the-effective-receptive-field-on-cnns/
#
# 3. Blog 2 on Receptive field: http://www.cs.toronto.edu/~wenjie/papers/nips16/top.pdf

# %% [markdown]
# # COCO
#
# ## Dataset Directory Structure
#
#     ../sample_dataset (root_dir)
#           |
#           |------kangaroo (coco_dir)
#           |         |
#           |         |----images (set_dir)
#           |                |
#           |                |---------img1.jpg
#           |                |---------img2.jpg
#           |                |---------..........(and so on)
#           |
#           |
#           |         |---annotations
#           |         |----|
#           |              |--------------------instances_Train.json  (instances_<set_dir>.json)
#           |              |--------------------classes.txt
#
#
#  - instances_Train.json -> In proper COCO format
#  - classes.txt          -> A list of classes in alphabetical order
#
#
# For TrainSet
#  - root_dir = "../sample_dataset";
#  - coco_dir = "kangaroo";
#  - set_dir = "Images";
#
#
# Note: Annotation file name too coincides against the set_dir

# %% [markdown]
# # Sample Dataset Credits
#
#     credits: https://github.com/experiencor/kangaroo

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/8_pytorch_rfbnet/lib/");

# %%
from train_detector import Detector

# %%
gtf = Detector();

# %%
#USing training set structured in format 1
root_dir = "Monk_Object_Detection/example_notebooks/sample_dataset";
coco_dir = "kangaroo";
set_dir = "Images";

# %%
#300
#512
gtf.Train_Dataset(root_dir, coco_dir, set_dir, batch_size=4,image_size=512, num_workers=3)

# %%
#vgg - 300, 512
#e_vgg - 300, 512
#mobilenet - 300, 512
gtf.Model(model_name="vgg", use_gpu=True, ngpu=1);

# %%
gtf.Set_HyperParams(lr=0.0001, momentum=0.9, weight_decay=0.0005, gamma=0.1, jaccard_threshold=0.5)

# %%
gtf.Train(epochs=10, log_iters=True, output_weights_dir="weights", saved_epoch_interval=10);
# Out:
# Loading base network...
# Initializing weights...
# Loading Dataset...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# ../sample_dataset_kangaroo_Images gt roidb loaded from /home/abhi/Desktop/Work/tess_tool/gui/v0.3/obj_det_models/Organization/v0.10_rfbnet/example_notebooks/8_pytorch_rfbnet/coco_cache/../sample_dataset_kangaroo_Images_gt_roidb.pkl
# Training RFB_vgg on COCO
# /home/abhi/.virtualenvs/monk_obj_8_pytorch_rfbnet/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch:1 || epochiter: 0/41|| Current iter 0|| Total iter 410 || L: 3.0127 C: 13.8585||Batch time: 11.1824 sec. ||LR: 0.00000100
# Epoch:1 || epochiter: 10/41|| Current iter 10|| Total iter 410 || L: 3.0146 C: 8.2253||Batch time: 0.4301 sec. ||LR: 0.00000583
# Epoch:1 || epochiter: 20/41|| Current iter 20|| Total iter 410 || L: 3.4626 C: 6.7073||Batch time: 0.4297 sec. ||LR: 0.00001066
# Epoch:1 || epochiter: 30/41|| Current iter 30|| Total iter 410 || L: 3.3533 C: 5.6294||Batch time: 0.4325 sec. ||LR: 0.00001549
# Epoch:1 || epochiter: 40/41|| Current iter 40|| Total iter 410 || L: 3.7569 C: 6.5177||Batch time: 0.4268 sec. ||LR: 0.00002032
# Epoch:2 || epochiter: 9/41|| Current iter 50|| Total iter 410 || L: 2.6997 C: 4.4858||Batch time: 0.4310 sec. ||LR: 0.00002515
# Epoch:2 || epochiter: 19/41|| Current iter 60|| Total iter 410 || L: 3.0167 C: 4.3184||Batch time: 0.4545 sec. ||LR: 0.00002998
# Epoch:2 || epochiter: 29/41|| Current iter 70|| Total iter 410 || L: 3.0867 C: 4.2520||Batch time: 0.4296 sec. ||LR: 0.00003480
# Epoch:2 || epochiter: 39/41|| Current iter 80|| Total iter 410 || L: 2.7996 C: 4.0632||Batch time: 0.4313 sec. ||LR: 0.00003963
# Epoch:3 || epochiter: 8/41|| Current iter 90|| Total iter 410 || L: 3.1269 C: 4.0913||Batch time: 0.4290 sec. ||LR: 0.00004446
# Epoch:3 || epochiter: 18/41|| Current iter 100|| Total iter 410 || L: 2.9647 C: 3.6093||Batch time: 0.4322 sec. ||LR: 0.00004929
# Epoch:3 || epochiter: 28/41|| Current iter 110|| Total iter 410 || L: 3.1398 C: 4.4620||Batch time: 0.4293 sec. ||LR: 0.00005412
# Epoch:3 || epochiter: 38/41|| Current iter 120|| Total iter 410 || L: 3.0708 C: 4.0916||Batch time: 0.4287 sec. ||LR: 0.00005895
# Epoch:4 || epochiter: 7/41|| Current iter 130|| Total iter 410 || L: 2.4878 C: 3.4557||Batch time: 0.4307 sec. ||LR: 0.00006378
# Epoch:4 || epochiter: 17/41|| Current iter 140|| Total iter 410 || L: 2.5447 C: 3.3783||Batch time: 0.4327 sec. ||LR: 0.00006861
# Epoch:4 || epochiter: 27/41|| Current iter 150|| Total iter 410 || L: 2.6647 C: 3.2134||Batch time: 0.4350 sec. ||LR: 0.00007344
# Epoch:4 || epochiter: 37/41|| Current iter 160|| Total iter 410 || L: 2.7753 C: 3.3659||Batch time: 0.4312 sec. ||LR: 0.00007827
# Epoch:5 || epochiter: 6/41|| Current iter 170|| Total iter 410 || L: 2.3354 C: 3.3223||Batch time: 0.4319 sec. ||LR: 0.00008310
# Epoch:5 || epochiter: 16/41|| Current iter 180|| Total iter 410 || L: 3.0239 C: 3.4411||Batch time: 0.4346 sec. ||LR: 0.00008793
# Epoch:5 || epochiter: 26/41|| Current iter 190|| Total iter 410 || L: 2.4571 C: 3.2062||Batch time: 0.4347 sec. ||LR: 0.00009276
# Epoch:5 || epochiter: 36/41|| Current iter 200|| Total iter 410 || L: 2.5282 C: 3.2195||Batch time: 0.4312 sec. ||LR: 0.00009759
# Epoch:6 || epochiter: 5/41|| Current iter 210|| Total iter 410 || L: 2.2176 C: 2.8803||Batch time: 0.4311 sec. ||LR: 0.00010000
# Epoch:6 || epochiter: 15/41|| Current iter 220|| Total iter 410 || L: 1.5554 C: 2.9049||Batch time: 0.4312 sec. ||LR: 0.00010000
# Epoch:6 || epochiter: 25/41|| Current iter 230|| Total iter 410 || L: 2.6953 C: 3.2353||Batch time: 0.4311 sec. ||LR: 0.00010000
# Epoch:6 || epochiter: 35/41|| Current iter 240|| Total iter 410 || L: 2.3859 C: 3.1323||Batch time: 0.4314 sec. ||LR: 0.00010000
# Epoch:7 || epochiter: 4/41|| Current iter 250|| Total iter 410 || L: 2.4012 C: 2.9558||Batch time: 0.4296 sec. ||LR: 0.00010000
# Epoch:7 || epochiter: 14/41|| Current iter 260|| Total iter 410 || L: 2.4431 C: 2.8478||Batch time: 0.4339 sec. ||LR: 0.00010000
# Epoch:7 || epochiter: 24/41|| Current iter 270|| Total iter 410 || L: 2.3212 C: 2.9361||Batch time: 0.4314 sec. ||LR: 0.00010000
# Epoch:7 || epochiter: 34/41|| Current iter 280|| Total iter 410 || L: 2.9982 C: 3.2346||Batch time: 0.4325 sec. ||LR: 0.00010000
# Epoch:8 || epochiter: 3/41|| Current iter 290|| Total iter 410 || L: 1.8862 C: 3.5167||Batch time: 0.4333 sec. ||LR: 0.00010000
# Epoch:8 || epochiter: 13/41|| Current iter 300|| Total iter 410 || L: 2.0476 C: 2.7370||Batch time: 0.4316 sec. ||LR: 0.00010000
# Epoch:8 || epochiter: 23/41|| Current iter 310|| Total iter 410 || L: 2.3555 C: 2.7066||Batch time: 0.4302 sec. ||LR: 0.00010000
# Epoch:8 || epochiter: 33/41|| Current iter 320|| Total iter 410 || L: 2.5783 C: 2.8991||Batch time: 0.4310 sec. ||LR: 0.00010000
# Epoch:9 || epochiter: 2/41|| Current iter 330|| Total iter 410 || L: 1.7187 C: 2.9482||Batch time: 0.4293 sec. ||LR: 0.00010000
# Epoch:9 || epochiter: 12/41|| Current iter 340|| Total iter 410 || L: 2.5560 C: 3.1297||Batch time: 0.4326 sec. ||LR: 0.00010000
# Epoch:9 || epochiter: 22/41|| Current iter 350|| Total iter 410 || L: 2.4487 C: 2.4986||Batch time: 0.4337 sec. ||LR: 0.00010000
# Epoch:9 || epochiter: 32/41|| Current iter 360|| Total iter 410 || L: 2.5419 C: 3.1059||Batch time: 0.4302 sec. ||LR: 0.00010000
# Epoch:10 || epochiter: 1/41|| Current iter 370|| Total iter 410 || L: 2.1328 C: 2.5258||Batch time: 0.4324 sec. ||LR: 0.00010000
# Epoch:10 || epochiter: 11/41|| Current iter 380|| Total iter 410 || L: 1.7555 C: 2.8680||Batch time: 0.4333 sec. ||LR: 0.00010000
# Epoch:10 || epochiter: 21/41|| Current iter 390|| Total iter 410 || L: 2.4598 C: 2.9556||Batch time: 0.4376 sec. ||LR: 0.00010000
# Epoch:10 || epochiter: 31/41|| Current iter 400|| Total iter 410 || L: 2.0002 C: 2.4035||Batch time: 0.4315 sec. ||LR: 0.00010000

# %% [markdown]
# # Inference

# %%
import os
import sys
sys.path.append("Monk_Object_Detection/8_pytorch_rfbnet/lib/");

# %%
from infer_detector import Infer

# %%
gtf = Infer();

# %%
gtf.Model(model_name="vgg", weights="weights/Final_RFB_vgg_COCO.pth", use_gpu=True)

# %%
class_file = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/annotations/classes.txt"
gtf.Image_Params(class_file, input_size=512)

# %%
gtf.Setup();
# Out:
# Finished loading model!

# %%
img_path = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/test/kg1.jpeg";
output = gtf.Predict(img_path, thresh=0.6, font_size=1, line_size=3)
from IPython.display import Image
Image(filename='output.png')
# Out:
# 1 1

# %%
img_path = "Monk_Object_Detection/example_notebooks/sample_dataset/kangaroo/test/kg3.jpeg";
output = gtf.Predict(img_path, thresh=0.4, font_size=1, line_size=3)
from IPython.display import Image
Image(filename='output.png')
# Out:
# 1 1
